# %% [markdown]
# # Koopman operator learning, a toy case: Duffing oscillator
#
# **-- PLEASE SUBMIT YOUR COMPLETED NOTEBOOK WITH CELL OUTPUTS --**

# %% [markdown]
# The aim of this notebook is to describe the dynamics of a non-linear dynamical system by means of the Koopman theory.
#
# ## Introduction
#
# We consider a quantity $x$ (a vector) which evolves with time, following a dynamical system. Think for example of the joint location of the planets in our solar system, which follows the law of gravitation.
#
# Formally, given an initial state $x(t=0) \in \mathbb{R}^n$ at time $t=0$, the time evolution of $x$ is governed by the following dynamical system:
# $$
# \dot{x}(t) = f(x(t)) \quad \text(1)
# $$
#
# where $\dot{x}(t) := \frac{dx(t)}{dt}$ is the temporal derivative, and $f:\mathbb{R}^n \rightarrow \mathbb{R}^n$ is a given map describing the dynamics.
#
# For a given $f$, it is not always possible to solve the differential equation (1) analytically. For this reason, instead, numerical schemes are usually employed, to integrate in time $t$ the equation (1), so as to propagate the initial condition $x(0)$ up to a desired time $T$; think of $x(T) = x(0) + \int_{t=0}^{T} f(x(t)) dt$. The discretization in time of eq (1) or of the integral introduces numerical approximations, and yields estimates of $x(T)$ of various quality depending on the discretization scheme.
#
# In the field of numerical simulations, discretization schemes have been studied for a long time, and numerical solvers already exist to provide good estimates of integrals (far better than with the naive discretization $x_{k+\delta} = x_k + \delta\,f(x_k)$ for a discrete time increment $\delta$, which induces a $O(\delta^2)$ error at each time step).
#
# The goal of this practical session is to make use of such numerical solvers to improve the learning of dynamical systems with neural networks.

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import sys
from tqdm import tqdm

from torch.utils.data import TensorDataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd

# arrange the dataset
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Duffing oscillator
#
# As a toy example, we consider the Duffing oscillator, where the state $x = (x_1, x_2) \in \mathbb{R}^2$ follows the dynamical system described by the following ODEs:
#
# $$
# \dot{x}_1 = x_2\\
# \dot{x}_2 = x_1 - x_1^3
# $$
#
# To integrate in time the ODEs, a 4th order Runge-Kutta scheme can be used.

# %%
def duffing(array_x: np.ndarray) -> np.ndarray:
    array_dx = np.zeros(array_x.shape)
    array_dx[0] = array_x[1]
    array_dx[1] = array_x[0] - array_x[0] ** 3
    return array_dx

# %%
t_max = 500  # Time-horizon integration
n_iter = 5000  # Number of time steps integration
n_initial_conditions = 60  # Number of initial conditions

dim_system = 2

# Generate initial conditions
matrix_x0 = (np.random.rand(n_initial_conditions, dim_system) - 0.5) * 4
array_t = np.linspace(0, t_max, n_iter)
array3d_xt = np.zeros((matrix_x0.shape[0], matrix_x0.shape[1], n_iter))

for i in tqdm(range(matrix_x0.shape[0])):
    # Lambda function is used as solve_ivp requires a function of the form f(t, x)
    ode_result = solve_ivp(lambda _t, array_x: duffing(array_x),
                           [0, t_max],
                           matrix_x0[i],
                           method='RK45',
                           t_eval=array_t)

    array3d_xt[i, :] = ode_result.y
# Out:
# 100%|██████████| 60/60 [00:03<00:00, 19.20it/s]

# %% [markdown]
# The following plot shows trajectories for different initial conditions:

# %%
fig = plt.figure(figsize=(20, 5))
ax = fig.add_subplot(131)
cm = plt.get_cmap("tab10")
print(cm)
for i in range(10):
    ax.plot(array3d_xt[i, 0, :], array3d_xt[i, 1, :], lw=0.5, color=cm(i))
    ax.plot(array3d_xt[i, 0, 0], array3d_xt[i, 1, 0], 'o', lw=1.5, color=cm(i))  #initial condition
ax.set_xlabel('$x_1$', fontsize=20)
ax.set_ylabel('$x_2$', fontsize=20)
plt.show()
# Out:
# <matplotlib.colors.ListedColormap object at 0x0000022087830410>

# %% [markdown]
# ## The Koopman operator
# ### Discontinuous in time case
# Given the discrete non-linear dynamical system
#
# $$
# x_{k+1} = F(x_k)
# $$
#
# where $F$ might be the $\delta$-discretised flow map of the continuous dynamical system in eq (1) given by
#
# $$
# x_{k+1} = F(x_k) := x_k + \int_{k}^{k + \delta} f(x(s))ds
# $$
#
# and $X = (x_k)_{k = 0}^N$ the discrete time series of the system state.
#
#
# The _Koopman_ theory states that there exists an infinite-dimensional linear operator $\mathcal{K}$ that advances in time all observable functions $(g_i)_{i = 1}^m$ given by $g_i: \mathbb{R}^n \rightarrow \mathbb{R}$
#
# $$
# \mathcal{K} g_i(x) = g_i \circ F(x)
# $$
#
# This way, the non-linear dynamics of $x$, described by $F$, can be turned into a **linear** dynamical system, described by $\mathcal{K}$, acting on another representation space, formed by the observable quantities $g_i(x)$.
#
# Indeed, let $g_i$ be an observable function and denoting ${g_i}_k := g_i(x_k)$, using the previous equation, the time evolution of the observables is given by
#
# $$
# {g_i}_{k+1} = g_i(x_{k+1}) = g_i(F(x_k)) = g_i \circ F(x_k) = \mathcal{K} g_i(x_k) = \mathcal{K} {g_i}_k
# $$
#
# then, the linearised dynamics of the observables is given by the following equation
#
# $$
# {g_i}_{k+1} = \mathcal{K} {g_i}_k
# $$
#
#
# It is then sufficient to find a function $g: \mathbb{R}^n \rightarrow \mathbb{R}^m$ with $m \gg n$ that embeds the state $x$ into a "larger enough" dimensional space $m$ such that the linear operator $\mathcal{K}$ can be inferred by a matrix $\mathbf{K} \in \mathbb{R}^{m \times m}$.
#
# To project back the dynamics from the Koopman space ($\mathbb{R}^m$, where $g(x)$ lives) to the phase space ($\mathbb{R}^n$, where $x$ lives), a supplementary function $\varphi: \mathbb{R}^m \rightarrow \mathbb{R}^n$ is needed. Going from $x$ to the Koopman space and back yields $\varphi \text{ o  } g = $ Id.
#
# Under this condition, the functions $g$, $\varphi$ and $\mathbf{K}$ can be parametrized $g_{\theta}$, $\varphi_{\rho}$ and $\mathbf{K}_{\phi}$, and the parameters $\theta$, $\rho$ and $\phi$ can be learned minimizing suitable loss functions.
#
# For this purpose, given a time series $X = \{x_k | k = 1 \ldots N \}$, the following conditions hold:
#
#
# 1.   Reconstruction error
#      $$
#      \Vert \varphi_\rho (g_\theta(x_k)) - x_k  \Vert = 0
#      $$
# 2.   Prediction error in Koopman space
#      $$
#      \Vert \mathbf{K_{\phi}} g_{\theta} ( x_k ) - g_{\theta} (x_{k+1})  \Vert = 0
#      $$
# 3.   Prediction error in the phase space
#      $$
#      \Vert \varphi_{\rho} \left( \mathbf{K_{\phi}} g_{\theta} ( x_k )\right) - x_{k+1} \Vert = 0
#      $$
#
# The last three errors can be used as loss functions to train three different neural networks. These different neural networks compose our architecture that can be summarized as in the following sketch:

# %% [markdown]
# ![architecture](./architecture.png)

# %%
# Flatten the trajectories w.r.t. initial conditions 
# and only keep data in the form of (dim_system, n_iter * n_initial_conditions)
matrix_x_data = array3d_xt[:, :, :-1].swapaxes(0, 1).reshape(2, -1).T
matrix_x_next_data = array3d_xt[:, :, 1:].swapaxes(0, 1).reshape(2, -1).T

(matrix_x_data_train,
 matrix_x_data_test,
 matrix_x_next_data_train,
 matrix_x_next_data_test) = train_test_split(matrix_x_data,
                                             matrix_x_next_data,
                                             test_size=0.2)

# Cast type to float32
matrix_x_data_train = matrix_x_data_train.astype(np.float32)
matrix_x_data_test = matrix_x_data_test.astype(np.float32)
matrix_x_next_data_train = matrix_x_next_data_train.astype(np.float32)
matrix_x_next_data_test = matrix_x_next_data_test.astype(np.float32)

print(matrix_x_data_train.shape,
      matrix_x_data_test.shape,
      matrix_x_next_data_train.shape,
      matrix_x_next_data_test.shape)
# Out:
# (239952, 2) (59988, 2) (239952, 2) (59988, 2)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type('torch.DoubleTensor')

batch_size = 2000  # data per batch

tensor2d_x_data_train      = torch.from_numpy(matrix_x_data_train).to(device)
tensor2d_x_next_data_train = torch.from_numpy(matrix_x_next_data_train).to(device)
tensor2d_x_data_test       = torch.from_numpy(matrix_x_data_test).to(device)
tensor2d_x_next_data_test  = torch.from_numpy(matrix_x_next_data_test).to(device)

torch_dataset_train = TensorDataset(tensor2d_x_data_train,
                                    tensor2d_x_next_data_train)

torch_dataset_test = TensorDataset(tensor2d_x_data_test,
                                   tensor2d_x_next_data_test)

train_dataloader = DataLoader(torch_dataset_train,
                              batch_size=batch_size,
                              shuffle=True)
test_dataloader = DataLoader(torch_dataset_test,
                             batch_size=batch_size,
                             shuffle=True)

# create the models
feature_dim = 2  # dimension of the Duffing oscillator
hidden_layer = 5  # number of hidden layers in g (ENCODER) and \varphi (DECODER) 
output_dim = 30  # dimension in Koopman space

# %%
class Encoder(nn.Module):
    def __init__(self, list_layer_dim: list):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1):
            input_dim = self.list_layer_dim[i]
            output_dim = self.list_layer_dim[i + 1]
            self.list_FC.append(nn.Linear(input_dim, output_dim))

    def forward(self, tensor2d_x):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Decoder(nn.Module):
    def __init__(self, list_layer_dim: list):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1, 0, -1):
            input_dim = self.list_layer_dim[i]
            output_dim = self.list_layer_dim[i - 1]
            self.list_FC.append(nn.Linear(input_dim, output_dim))

    def forward(self, tensor2d_x: torch.Tensor):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Autoencoder(nn.Module):
    def __init__(self, feature_dim: int, hidden_layer: int, output_dim: int):
        super().__init__()
        list_layer_dim = \
            [output_dim if i == hidden_layer
             else feature_dim + i * (output_dim - feature_dim) // hidden_layer
             for i in range(hidden_layer + 1)]
        self.encoder = Encoder(list_layer_dim)
        self.decoder = Decoder(list_layer_dim)

    def forward(self, tensor2d_x: torch.Tensor):
        tensor2d_x = self.Encoder(tensor2d_x)
        return self.Decoder(tensor2d_x)

# %%
def reset_seed(seed=42):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# The Koopman operator $\mathbf{K}$ (which is linear, and thus a matrix) must have a [spectral radius](https://en.wikipedia.org/wiki/Spectral_radius) $\rho(\mathbf{K})\le 1$. Such condition will provide a stable -or at least a marginally stable- Koopman operator. To fulfill this requirement, we might leverage on the Perron-Frobenius theorem.
#
# The Perron-Frobenius th. states: if $\mathbf{K}$ is a $m \times m$ positive matrix i.e. $k_{ij} > 0$ for $1 \le i,j \le m$, then the following inequality holds:
#
# $$
# \min_i \sum_j k_{ij} \le \rho(\mathbf{K}) \le \max_i \sum_j k_{ij}
# $$

# %% [markdown]
# **Question 1.** : Complete the `KoopmanModule` class to enforce $\rho(\mathbf{K})\le 1$, using the Perron-Frobenius theorem. Check that the initialization fulfills this property.

# %%
class KoopmanOperator(nn.Module):
    def __init__(self, koopman_operator_dim):
        super().__init__()
        self.koopman_operator_dim = koopman_operator_dim


        self.koopman_matrix = nn.Parameter( torch.randn(koopman_operator_dim, koopman_operator_dim) )
        
      
    def forward(self, tensor2d_x):
        if tensor2d_x.shape[1] != self.koopman_operator_dim:
            sys.exit(f'Wrong Input Features ({tensor2d_x.shape[1]}). Please use tensor'
                     f' with {self.koopman_operator_dim} Input Features')
                    
        max_K = self.koopman_matrix.data.sum(axis=1).max().item()
       
        if max_K > 1 : 
          self.koopman_matrix.data  = self.koopman_matrix.data / max_K
        
        return torch.matmul(tensor2d_x, self.koopman_matrix.data.t())

# dim_observable = 10
# koopman_operator = KoopmanOperator(dim_observable)

# %%
autoencoder = Autoencoder(feature_dim, hidden_layer, output_dim).to(device)
koopman_operator = KoopmanOperator(output_dim).to(device)
print(autoencoder)
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=2, out_features=7, bias=True)
#       (1): Linear(in_features=7, out_features=13, bias=True)
#       (2): Linear(in_features=13, out_features=18, bias=True)
#       (3): Linear(in_features=18, out_features=24, bias=True)
#       (4): Linear(in_features=24, out_features=30, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=30, out_features=24, bias=True)
#       (1): Linear(in_features=24, out_features=18, bias=True)
#       (2): Linear(in_features=18, out_features=13, bias=True)
#       (3): Linear(in_features=13, out_features=7, bias=True)
#       (4): Linear(in_features=7, out_features=2, bias=True)
#     )
#   )
# )

# %%
learning_rate_autoencoder = 0.0001
learning_rate_koopman = 0.00001

optimiser_autoencoder = torch.optim.Adam(autoencoder.parameters(),
                                         lr=learning_rate_autoencoder)

optimiser_koopman = torch.optim.Adam(koopman_operator.parameters(),
                                     lr=learning_rate_koopman)

# %% [markdown]
# **Question 2.** : Define a function to compute the loss to be minimized. It should at least include the 3 terms listed above:
# - Reconstruction error
# - Prediction error in the Koopman space
# - Prediction error in the phase space
#
# Because the different objectives outlined by these losses may compete, the training can be difficult. You may try different variations on these losses and comment your findings. In order to improve the training process, one can for instance:
# - Add a multiplicative factor in front of each loss component, to balance their importance; how the scales of different losses are related?
# - We can refine the loss acting upon the latent space, by using a variational autoencoder approach. This is similar to the Gaussian likelihood used in the first practical (TD1). We want the prediction in the latent space (i.e. the Koopman space) to be a normal distribution $\mathcal{N}(0, 1)$ . Add a corresponding loss for the latent space. Difference to 0 mean and 1 standard deviation must be thus included in the loss;
# - Freeze the gradients of one part of the network, for instance the encoder, for one specific objective, using the [`requires_grad`](https://pytorch.org/docs/stable/generated/torch.Tensor.requires_grad_.html) property. For instance:
# ```python
# criterion = nn.MSELoss()
# ...
# # Compute one part loss_l of the total loss
# # First deactivate gradient computation for irrelevant parts of the architecture
# for p in autoencoder.encoder.parameters():
#     p.requires_grad = False
# loss_l = criterion(pred, target)
# # Restore the gradient computation
# for p in autoencoder.encoder.parameters():
#     p.requires_grad = True
# ...
# total_loss = loss_1 + ... + loss_l + ...
# ```

# %%
def sum_parameters_to_one(parameters: tuple):
      """ Simple function to ensure the sum of the coefficients is equal to 1
          We keep the modified parameter value and set the three others to to an equal contribution
          of the remainder
      """
      idx = 0

      while idx != len(parameters) and (parameters[idx] == 0.25):
          idx += 1

      if idx != len(parameters):
          remaining_sum = 1 - parameters[idx]
          num_elements = len(parameters) - 1

          if num_elements > 0:
              for i in range(len(parameters)):
                  if i != idx:
                      parameters[i] = remaining_sum / num_elements

      return parameters

# %%
def loss_koopman(tensor2d_x: torch.Tensor, 
                 tensor2d_x_next: torch.Tensor,
                 tensor2d_decoded_x: torch.Tensor,
                 tensor2d_observable_next: torch.Tensor,
                 tensor2d_koopman_observable_next: torch.Tensor,
                 tensor2d_predict_x_next: torch.Tensor,
                 tensor2d_observable: torch.Tensor,
                 alpha: float = 0.25,
                 beta:  float = 0.25,
                 gamma: float = 0.25,
                 delta: float = 0.25,
                 experiment_mode: bool = False):
    
    if experiment_mode:
      print("running experiment")
      alpha, beta, gamma, delta = sum_parameters_to_one([alpha, beta, gamma, delta])

    for p in autoencoder.encoder.parameters():
      p.requires_grad = False
    
    reconst_loss  = F.mse_loss(tensor2d_decoded_x, tensor2d_x)
    koopeman_loss = F.mse_loss(tensor2d_koopman_observable_next, tensor2d_observable_next)
    phase_loss    = F.mse_loss(tensor2d_predict_x_next, tensor2d_x_next)
    vae_loss      = torch.abs(torch.mean(tensor2d_observable)) + torch.abs(torch.std(tensor2d_observable)-1)
    
    for p in autoencoder.encoder.parameters():
      p.requires_grad = True

    total_loss = alpha * reconst_loss + beta * koopeman_loss + gamma * phase_loss + delta * vae_loss
 
    return total_loss, reconst_loss, koopeman_loss, phase_loss, vae_loss

# %% [markdown]
# 1.   Reconstruction error
# $$
# \Vert \varphi_\rho (g_\theta(x_k)) - x_k  \Vert = 0
# $$
# 2.   Prediction error in Koopman space
# $$
# \Vert \mathbf{K_{\phi}} g_{\theta} ( x_k ) - g_{\theta} (x_{k+1})  \Vert = 0
# $$
# 3.   Prediction error in the phase space
# $$
# \Vert \varphi_{\rho} \left( \mathbf{K_{\phi}} g_{\theta} ( x_k )\right) - x_{k+1} \Vert = 0
# $$

# %% [markdown]
# **Question 3.**: Display the different intermediate losses computed in the function `LOSS` above. How do they evolve in time? Justify your final choice.

# %%
n_batch = len(train_dataloader)
n_epoch = 50  # To be tuned 
test_freq = 50

def eval_hyperparameter(experiment_mode, **kwargs):

    # reset_seed()

    global autoencoder
    global koopman_operator

    autoencoder           = Autoencoder(feature_dim, hidden_layer, output_dim).to(device)
    koopman_operator      = KoopmanOperator(output_dim).to(device)
    optimiser_autoencoder = torch.optim.Adam(autoencoder.parameters(),
                                            lr=learning_rate_autoencoder)

    optimiser_koopman     = torch.optim.Adam(koopman_operator.parameters(),
                                             lr=learning_rate_koopman)

    total_loss_array = torch.zeros(n_epoch)
    test_loss_array  = torch.zeros(n_epoch // test_freq)

    for epoch in range(n_epoch):
        autoencoder.train()
        koopman_operator.train()

        total_train_loss = 0
        total_loss1, total_loss2, total_loss3, total_loss4 = 0, 0, 0, 0

        for tensor2d_batch_x, tensor2d_batch_x_next in train_dataloader:
            # tensor2d_batch_x = tensor2d_batch_x.to(device)           # they are already loaded to the device
            # tensor2d_batch_x_next = tensor2d_batch_x_next.to(device) 

            optimiser_autoencoder.zero_grad()
            optimiser_koopman.zero_grad()

            tensor2d_observable = autoencoder.encoder(tensor2d_batch_x)
            tensor2d_observable_next = autoencoder.encoder(tensor2d_batch_x_next) 

            tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable)

            tensor2d_koopman_observable_next = koopman_operator(tensor2d_observable)

            tensor2d_predict_x_next = autoencoder.decoder(tensor2d_koopman_observable_next)

            losses = loss_koopman(tensor2d_batch_x,
                                        tensor2d_batch_x_next, 
                                        tensor2d_decoded_x, 
                                        tensor2d_observable_next, 
                                        tensor2d_koopman_observable_next, 
                                        tensor2d_predict_x_next,
                                        tensor2d_observable,
                                        experiment_mode=experiment_mode,
                                        **kwargs) 

            tensor_loss_val = losses[0]

            tensor_loss_val.backward()
            optimiser_autoencoder.step()
            optimiser_koopman.step()

            if epoch % 1 == 0:
                total_train_loss += tensor_loss_val.item()
                total_loss1      += losses[1].item()
                total_loss2      += losses[2].item()
                total_loss3      += losses[3].item()
                total_loss4      += losses[4].item()

        total_loss_array[epoch] = total_train_loss
        
        if epoch % 1 == 0:
            print(f"{epoch:<3}/{n_epoch} - "
                  f"total_train_loss: {total_train_loss:.5f} - "
                  f"reconst: {total_loss1:.5f} - "
                  f"koopeman: {total_loss2:.5f} - "
                  f"phase: {total_loss3:.5f} - "
                  f"VAE: {total_loss4:.5f}"
            )

        if epoch % test_freq == 0 and epoch != 0:
            autoencoder.eval()
            koopman_operator.eval()
            tensor_loss_val = None
            with torch.no_grad():
                total_test_loss = 0
                test_loss1, test_loss2, test_loss3, test_loss4 = 0, 0, 0, 0

                for tensor2d_batch_x, tensor2d_batch_x_next in test_dataloader:
                    tensor2d_batch_x = tensor2d_batch_x.to(device)
                    tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

                    tensor2d_observable = \
                        autoencoder.encoder(tensor2d_batch_x)
                    tensor2d_observable_next = \
                        autoencoder.encoder(tensor2d_batch_x_next)
                    tensor2d_decoded_x = \
                        autoencoder.decoder(tensor2d_observable)
                    tensor2d_koopman_observable_next = \
                        koopman_operator(tensor2d_observable)
                    tensor2d_predict_x_next = \
                        autoencoder.decoder(tensor2d_koopman_observable_next)

                    test_losses = loss_koopman(tensor2d_batch_x,
                                                tensor2d_batch_x_next,
                                                tensor2d_decoded_x,
                                                tensor2d_observable_next,
                                                tensor2d_koopman_observable_next,
                                                tensor2d_predict_x_next,
                                                tensor2d_observable,
                                                experiment_mode=experiment_mode,
                                                **kwargs)
                    
                tensor_loss_val = test_losses[0]
                total_test_loss += tensor_loss_val.item()
                test_loss1      += test_losses[1]
                test_loss2      += test_losses[2]
                test_loss3      += test_losses[3]
                test_loss4      += test_losses[4]

                test_loss_array[epoch//test_freq] = total_test_loss

                try:
                    plot_results()

                except:
                    print("Run the next cells")

                print(f"{epoch:<3}/{n_epoch} - "
                  f"total_test_loss:  {total_test_loss:.5f} - "
                  f"reconst: {test_loss1:.5f} - "
                  f"koopeman: {test_loss2:.5f} - "
                  f"phase: {test_loss3:.5f} - "
                  f"VAE: {test_loss4:.5f}"
            )
        
    return total_loss_array, test_loss_array

# %%
value_set = (0.1, 0.3, 0.5, 0.8, 1.0)

n_epoch = 80

hyperparameters = {
    "alpha": value_set,
    "beta":  value_set,
    "gamma": value_set
}

_, ax = plt.subplots(len(hyperparameters), 2, figsize=(20, 15))
x_plot_train = np.arange(n_epoch)
x_plot_test  = np.arange(n_epoch//test_freq)

if len(hyperparameters) > 1:
    for a in ax:
        a[0].set_ylabel("Loss")
        a[1].set_ylabel("Loss")
        a[0].set_xlabel("Epoch")
        a[1].set_xlabel("Epoch")

for idx, (param, values) in enumerate(hyperparameters.items()):
    
    for v_idx, value in enumerate(values):
        print(f"{'-'*10}Parameter: {param}={value}{'-'*10}")
        train_loss, test_loss = eval_hyperparameter(True, **{param: value})

        ax[idx][0].plot(x_plot_train, train_loss, label=f"{param}={value:2g}")
        ax[idx][1].plot(x_plot_test, test_loss,  label=f"{param}={value:2g}")

        ax[idx][0].legend(loc='upper right')
        ax[idx][1].legend(loc='upper right')
        
plt.show()
# Out:
# ----------Parameter: alpha=0.1----------
# 0  /80 - total_train_loss: 22.22334 - reconst: 39.19104 - koopeman: 0.57325 - phase: 39.11774 - VAE: 21.32311
# 1  /80 - total_train_loss: 22.05057 - reconst: 39.08829 - koopeman: 0.61022 - phase: 39.02149 - VAE: 20.84077
# 2  /80 - total_train_loss: 21.90095 - reconst: 38.99274 - koopeman: 0.67375 - phase: 38.93189 - VAE: 20.39995
# 3  /80 - total_train_loss: 21.80233 - reconst: 38.89712 - koopeman: 0.76954 - phase: 38.84362 - VAE: 20.09556
# 4  /80 - total_train_loss: 21.70480 - reconst: 38.79141 - koopeman: 0.87140 - phase: 38.74785 - VAE: 19.79961
# 5  /80 - total_train_loss: 21.59695 - reconst: 38.66412 - koopeman: 0.98200 - phase: 38.63426 - VAE: 19.48553
# 6  /80 - total_train_loss: 21.46936 - reconst: 38.48870 - koopeman: 1.10312 - phase: 38.48120 - VAE: 19.15066
# 7  /80 - total_train_loss: 21.30280 - reconst: 38.21700 - koopeman: 1.23731 - phase: 38.24991 - VAE: 18.78310
# 8  /80 - total_train_loss: 21.06382 - reconst: 37.75293 - koopeman: 1.38842 - phase: 37.86189 - VAE: 18.37812
# 9  /80 - total_train_loss: 20.68643 - reconst: 36.91348 - koopeman: 1.56385 - phase: 37.16623 - VAE: 17.92020
# 10 /80 - total_train_loss: 20.05408 - reconst: 35.38345 - koopeman: 1.77678 - phase: 35.90034 - VAE: 17.37534
# 10 /80 - total_test_loss:  0.81698 - reconst: 1.42873 - koopeman: 0.07926 - phase: 1.45690 - VAE: 0.71085
# 11 /80 - total_train_loss: 19.03137 - reconst: 32.83957 - koopeman: 2.04756 - phase: 33.73452 - VAE: 16.70929
# 12 /80 - total_train_loss: 17.58086 - reconst: 29.32420 - koopeman: 2.39621 - phase: 30.53779 - VAE: 15.89414
# 13 /80 - total_train_loss: 15.89828 - reconst: 25.51886 - koopeman: 2.82444 - phase: 26.71582 - VAE: 14.94773
# 14 /80 - total_train_loss: 14.35966 - reconst: 22.41974 - koopeman: 3.29375 - phase: 23.14858 - VAE: 13.94993
# 15 /80 - total_train_loss: 13.26052 - reconst: 20.59290 - koopeman: 3.72645 - phase: 20.60017 - VAE: 13.01081
# 16 /80 - total_train_loss: 12.63163 - reconst: 19.82831 - koopeman: 4.04450 - phase: 19.21325 - VAE: 12.23826
# 17 /80 - total_train_loss: 12.29693 - reconst: 19.55105 - koopeman: 4.23092 - phase: 18.59866 - VAE: 11.64317
# 18 /80 - total_train_loss: 12.09106 - reconst: 19.40313 - koopeman: 4.32935 - phase: 18.34456 - VAE: 11.16193
# 19 /80 - total_train_loss: 11.93140 - reconst: 19.30492 - koopeman: 4.39568 - phase: 18.22865 - VAE: 10.71203
# 20 /80 - total_train_loss: 11.79144 - reconst: 19.24041 - koopeman: 4.46285 - phase: 18.16225 - VAE: 10.26625
# 20 /80 - total_test_loss:  0.48968 - reconst: 0.80325 - koopeman: 0.18825 - phase: 0.75974 - VAE: 0.41652
# 21 /80 - total_train_loss: 11.65206 - reconst: 19.19008 - koopeman: 4.54490 - phase: 18.11599 - VAE: 9.78261
# 22 /80 - total_train_loss: 11.50860 - reconst: 19.15532 - koopeman: 4.65324 - phase: 18.07780 - VAE: 9.24587
# 23 /80 - total_train_loss: 11.36278 - reconst: 19.12655 - koopeman: 4.78922 - phase: 18.04655 - VAE: 8.66466
# 24 /80 - total_train_loss: 11.20711 - reconst: 19.10363 - koopeman: 4.95814 - phase: 18.01904 - VAE: 8.01198
# 25 /80 - total_train_loss: 11.04762 - reconst: 19.07741 - koopeman: 5.16044 - phase: 17.99815 - VAE: 7.30768
# 26 /80 - total_train_loss: 10.87960 - reconst: 19.06065 - koopeman: 5.40304 - phase: 17.97813 - VAE: 6.53061
# 27 /80 - total_train_loss: 10.69934 - reconst: 19.04793 - koopeman: 5.68403 - phase: 17.96205 - VAE: 5.66907
# 28 /80 - total_train_loss: 10.51612 - reconst: 19.02782 - koopeman: 6.00568 - phase: 17.94756 - VAE: 4.75790
# 29 /80 - total_train_loss: 10.32503 - reconst: 18.99644 - koopeman: 6.36838 - phase: 17.93681 - VAE: 3.77942
# 30 /80 - total_train_loss: 10.12613 - reconst: 18.96805 - koopeman: 6.77577 - phase: 17.92431 - VAE: 2.73100
# 30 /80 - total_test_loss:  0.41927 - reconst: 0.79574 - koopeman: 0.29216 - phase: 0.75369 - VAE: 0.08646
# 31 /80 - total_train_loss: 9.92092 - reconst: 18.93142 - koopeman: 7.22545 - phase: 17.91120 - VAE: 1.62261
# 32 /80 - total_train_loss: 9.71101 - reconst: 18.87599 - koopeman: 7.69594 - phase: 17.89853 - VAE: 0.48358
# 33 /80 - total_train_loss: 9.58368 - reconst: 18.65912 - koopeman: 7.63682 - phase: 17.88299 - VAE: 0.20609
# 34 /80 - total_train_loss: 9.48397 - reconst: 18.54503 - koopeman: 7.44277 - phase: 17.82537 - VAE: 0.16342
# 35 /80 - total_train_loss: 9.39470 - reconst: 18.42982 - koopeman: 7.21811 - phase: 17.75106 - VAE: 0.20324
# 36 /80 - total_train_loss: 9.31405 - reconst: 18.29427 - koopeman: 7.04486 - phase: 17.68163 - VAE: 0.22225
# 37 /80 - total_train_loss: 9.22559 - reconst: 18.16483 - koopeman: 6.92447 - phase: 17.60111 - VAE: 0.17145
# 38 /80 - total_train_loss: 9.14239 - reconst: 17.98554 - koopeman: 6.75276 - phase: 17.52259 - VAE: 0.20411
# 39 /80 - total_train_loss: 9.05850 - reconst: 17.80977 - koopeman: 6.66052 - phase: 17.42622 - VAE: 0.17169
# 40 /80 - total_train_loss: 8.96778 - reconst: 17.59069 - koopeman: 6.54999 - phase: 17.32120 - VAE: 0.15783
# 40 /80 - total_test_loss:  0.37103 - reconst: 0.72482 - koopeman: 0.26888 - phase: 0.72058 - VAE: 0.00569
# 41 /80 - total_train_loss: 8.87526 - reconst: 17.33954 - koopeman: 6.44982 - phase: 17.18815 - VAE: 0.16640
# 42 /80 - total_train_loss: 8.77509 - reconst: 17.04904 - koopeman: 6.35376 - phase: 17.03155 - VAE: 0.18196
# 43 /80 - total_train_loss: 8.65773 - reconst: 16.74438 - koopeman: 6.25359 - phase: 16.82741 - VAE: 0.19663
# 44 /80 - total_train_loss: 8.50997 - reconst: 16.38197 - koopeman: 6.21195 - phase: 16.56500 - VAE: 0.12897
# 45 /80 - total_train_loss: 8.34079 - reconst: 15.92497 - koopeman: 6.09789 - phase: 16.22547 - VAE: 0.17096
# 46 /80 - total_train_loss: 8.13033 - reconst: 15.37301 - koopeman: 6.05556 - phase: 15.77657 - VAE: 0.14463
# 47 /80 - total_train_loss: 7.87775 - reconst: 14.63901 - koopeman: 5.97555 - phase: 15.20567 - VAE: 0.19829
# 48 /80 - total_train_loss: 7.54828 - reconst: 13.72278 - koopeman: 5.94640 - phase: 14.47693 - VAE: 0.16334
# 49 /80 - total_train_loss: 7.17199 - reconst: 12.59378 - koopeman: 5.88559 - phase: 13.58157 - VAE: 0.24156
# 50 /80 - total_train_loss: 6.71471 - reconst: 11.33451 - koopeman: 5.88857 - phase: 12.51020 - VAE: 0.20541
# 50 /80 - total_test_loss:  0.27209 - reconst: 0.44775 - koopeman: 0.24357 - phase: 0.50012 - VAE: 0.01402
# 51 /80 - total_train_loss: 6.20823 - reconst: 10.03372 - koopeman: 5.89511 - phase: 11.31086 - VAE: 0.14354
# 52 /80 - total_train_loss: 5.70084 - reconst: 8.76120 - koopeman: 5.87407 - phase: 10.03452 - VAE: 0.17382
# 53 /80 - total_train_loss: 5.21045 - reconst: 7.61867 - koopeman: 5.87928 - phase: 8.74742 - VAE: 0.20190
# 54 /80 - total_train_loss: 4.75472 - reconst: 6.68148 - koopeman: 5.88246 - phase: 7.57109 - VAE: 0.16835
# 55 /80 - total_train_loss: 4.37857 - reconst: 5.94282 - koopeman: 5.84831 - phase: 6.57487 - VAE: 0.19113
# 56 /80 - total_train_loss: 4.08055 - reconst: 5.44954 - koopeman: 5.86056 - phase: 5.78656 - VAE: 0.13819
# 57 /80 - total_train_loss: 3.86729 - reconst: 5.05815 - koopeman: 5.81117 - phase: 5.21709 - VAE: 0.17665
# 58 /80 - total_train_loss: 3.69614 - reconst: 4.77222 - koopeman: 5.76738 - phase: 4.78719 - VAE: 0.17515
# 59 /80 - total_train_loss: 3.55019 - reconst: 4.51517 - koopeman: 5.73779 - phase: 4.45582 - VAE: 0.13530
# 60 /80 - total_train_loss: 3.44540 - reconst: 4.26151 - koopeman: 5.70343 - phase: 4.17969 - VAE: 0.18105
# 60 /80 - total_test_loss:  0.13987 - reconst: 0.17100 - koopeman: 0.23553 - phase: 0.16953 - VAE: 0.00418
# 61 /80 - total_train_loss: 3.33022 - reconst: 4.01326 - koopeman: 5.61796 - phase: 3.93354 - VAE: 0.21150
# 62 /80 - total_train_loss: 3.22681 - reconst: 3.79638 - koopeman: 5.58160 - phase: 3.70023 - VAE: 0.20875
# 63 /80 - total_train_loss: 3.11831 - reconst: 3.55400 - koopeman: 5.53222 - phase: 3.49154 - VAE: 0.18594
# 64 /80 - total_train_loss: 3.01605 - reconst: 3.35021 - koopeman: 5.50170 - phase: 3.28253 - VAE: 0.15254
# 65 /80 - total_train_loss: 2.91845 - reconst: 3.13435 - koopeman: 5.45891 - phase: 3.09255 - VAE: 0.13192
# 66 /80 - total_train_loss: 2.83132 - reconst: 2.93303 - koopeman: 5.40869 - phase: 2.91067 - VAE: 0.14071
# 67 /80 - total_train_loss: 2.77398 - reconst: 2.73707 - koopeman: 5.32484 - phase: 2.74256 - VAE: 0.26684
# 68 /80 - total_train_loss: 2.67763 - reconst: 2.58323 - koopeman: 5.31149 - phase: 2.57526 - VAE: 0.17761
# 69 /80 - total_train_loss: 2.60063 - reconst: 2.42355 - koopeman: 5.29711 - phase: 2.42561 - VAE: 0.13820
# 70 /80 - total_train_loss: 2.53335 - reconst: 2.26717 - koopeman: 5.24032 - phase: 2.29119 - VAE: 0.15727
# 70 /80 - total_test_loss:  0.10534 - reconst: 0.09190 - koopeman: 0.21606 - phase: 0.09290 - VAE: 0.01154
# 71 /80 - total_train_loss: 2.46969 - reconst: 2.14666 - koopeman: 5.21903 - phase: 2.16120 - VAE: 0.13653
# 72 /80 - total_train_loss: 2.41903 - reconst: 2.02396 - koopeman: 5.18233 - phase: 2.04588 - VAE: 0.16056
# 73 /80 - total_train_loss: 2.36429 - reconst: 1.91479 - koopeman: 5.15801 - phase: 1.94091 - VAE: 0.14379
# 74 /80 - total_train_loss: 2.32957 - reconst: 1.81622 - koopeman: 5.11438 - phase: 1.84646 - VAE: 0.19898
# 75 /80 - total_train_loss: 2.28240 - reconst: 1.73922 - koopeman: 5.09055 - phase: 1.75605 - VAE: 0.18167
# 76 /80 - total_train_loss: 2.22931 - reconst: 1.64359 - koopeman: 5.04117 - phase: 1.68261 - VAE: 0.15940
# 77 /80 - total_train_loss: 2.19968 - reconst: 1.58773 - koopeman: 5.03846 - phase: 1.60480 - VAE: 0.15978
# 78 /80 - total_train_loss: 2.16452 - reconst: 1.50364 - koopeman: 4.99800 - phase: 1.54579 - VAE: 0.17006
# 79 /80 - total_train_loss: 2.13038 - reconst: 1.46048 - koopeman: 4.97429 - phase: 1.48038 - VAE: 0.15979
# ----------Parameter: alpha=0.3----------
# 0  /80 - total_train_loss: 25.99239 - reconst: 39.17843 - koopeman: 0.57209 - phase: 39.12227 - VAE: 21.32935
# 1  /80 - total_train_loss: 25.83246 - reconst: 39.05299 - koopeman: 0.60768 - phase: 39.03661 - VAE: 20.85524
# 2  /80 - total_train_loss: 25.69158 - reconst: 38.93416 - koopeman: 0.67018 - phase: 38.95971 - VAE: 20.41869
# 3  /80 - total_train_loss: 25.58910 - reconst: 38.80800 - koopeman: 0.76619 - phase: 38.88714 - VAE: 20.11823
# 4  /80 - total_train_loss: 25.48304 - reconst: 38.66230 - koopeman: 0.86948 - phase: 38.81245 - VAE: 19.82243
# 5  /80 - total_train_loss: 25.36108 - reconst: 38.47573 - koopeman: 0.98264 - phase: 38.72949 - VAE: 19.50943
# 6  /80 - total_train_loss: 25.20674 - reconst: 38.20784 - koopeman: 1.10725 - phase: 38.62300 - VAE: 19.17428
# 7  /80 - total_train_loss: 24.98939 - reconst: 37.78599 - koopeman: 1.24582 - phase: 38.46331 - VAE: 18.80627
# 8  /80 - total_train_loss: 24.64877 - reconst: 37.06622 - koopeman: 1.40404 - phase: 38.18332 - VAE: 18.39365
# 9  /80 - total_train_loss: 24.07079 - reconst: 35.78676 - koopeman: 1.59289 - phase: 37.64314 - VAE: 17.91295
# 10 /80 - total_train_loss: 23.08851 - reconst: 33.61414 - koopeman: 1.83262 - phase: 36.57934 - VAE: 17.32062
# 10 /80 - total_test_loss:  0.93379 - reconst: 1.33995 - koopeman: 0.08242 - phase: 1.48993 - VAE: 0.70681
# 11 /80 - total_train_loss: 21.57969 - reconst: 30.43414 - koopeman: 2.14816 - phase: 34.63727 - VAE: 16.56934
# 12 /80 - total_train_loss: 19.62423 - reconst: 26.63419 - koopeman: 2.55500 - phase: 31.65846 - VAE: 15.64644
# 13 /80 - total_train_loss: 17.57805 - reconst: 23.08861 - koopeman: 3.03750 - phase: 28.00820 - VAE: 14.60341
# 14 /80 - total_train_loss: 15.89172 - reconst: 20.62019 - koopeman: 3.53363 - phase: 24.50518 - VAE: 13.55688
# 15 /80 - total_train_loss: 14.79221 - reconst: 19.38653 - koopeman: 3.95086 - phase: 21.88639 - VAE: 12.63237
# 16 /80 - total_train_loss: 14.18815 - reconst: 18.91453 - koopeman: 4.22456 - phase: 20.32708 - VAE: 11.93605
# 17 /80 - total_train_loss: 13.85040 - reconst: 18.69566 - koopeman: 4.36632 - phase: 19.50930 - VAE: 11.44595
# 18 /80 - total_train_loss: 13.62762 - reconst: 18.52978 - koopeman: 4.43107 - phase: 19.06764 - VAE: 11.08136
# 19 /80 - total_train_loss: 13.45356 - reconst: 18.37841 - koopeman: 4.46512 - phase: 18.79008 - VAE: 10.77356
# 20 /80 - total_train_loss: 13.30267 - reconst: 18.23306 - koopeman: 4.49142 - phase: 18.58536 - VAE: 10.49213
# 20 /80 - total_test_loss:  0.55277 - reconst: 0.75916 - koopeman: 0.18860 - phase: 0.77471 - VAE: 0.42963
# 21 /80 - total_train_loss: 13.15724 - reconst: 18.07625 - koopeman: 4.52014 - phase: 18.42110 - VAE: 10.20603
# 22 /80 - total_train_loss: 13.01153 - reconst: 17.90218 - koopeman: 4.55835 - phase: 18.27778 - VAE: 9.91050
# 23 /80 - total_train_loss: 12.85949 - reconst: 17.70271 - koopeman: 4.61014 - phase: 18.14181 - VAE: 9.59954
# 24 /80 - total_train_loss: 12.69259 - reconst: 17.46365 - koopeman: 4.67807 - phase: 18.00409 - VAE: 9.26138
# 25 /80 - total_train_loss: 12.50452 - reconst: 17.15922 - koopeman: 4.76544 - phase: 17.85640 - VAE: 8.90709
# 26 /80 - total_train_loss: 12.28111 - reconst: 16.76796 - koopeman: 4.87896 - phase: 17.67708 - VAE: 8.51849
# 27 /80 - total_train_loss: 11.99902 - reconst: 16.22981 - koopeman: 5.02454 - phase: 17.44570 - VAE: 8.08726
# 28 /80 - total_train_loss: 11.63278 - reconst: 15.46172 - koopeman: 5.21101 - phase: 17.12959 - VAE: 7.63481
# 29 /80 - total_train_loss: 11.13849 - reconst: 14.36692 - koopeman: 5.45809 - phase: 16.66450 - VAE: 7.14204
# 30 /80 - total_train_loss: 10.48466 - reconst: 12.92511 - koopeman: 5.79126 - phase: 15.95058 - VAE: 6.57442
# 30 /80 - total_test_loss:  0.42447 - reconst: 0.51160 - koopeman: 0.24941 - phase: 0.65249 - VAE: 0.25949
# 31 /80 - total_train_loss: 9.68002 - reconst: 11.21252 - koopeman: 6.21918 - phase: 14.90828 - VAE: 5.94226
# 32 /80 - total_train_loss: 8.77776 - reconst: 9.42146 - koopeman: 6.72885 - phase: 13.52322 - VAE: 5.25360
# 33 /80 - total_train_loss: 7.89913 - reconst: 7.90715 - koopeman: 7.28736 - phase: 11.88652 - VAE: 4.51318
# 34 /80 - total_train_loss: 7.17908 - reconst: 6.93840 - koopeman: 7.77428 - phase: 10.28806 - VAE: 3.78434
# 35 /80 - total_train_loss: 6.64215 - reconst: 6.41309 - koopeman: 8.11044 - phase: 8.98932 - VAE: 3.12116
# 36 /80 - total_train_loss: 6.23329 - reconst: 6.08682 - koopeman: 8.30301 - phase: 8.05507 - VAE: 2.53013
# 37 /80 - total_train_loss: 5.89786 - reconst: 5.83969 - koopeman: 8.43699 - phase: 7.38033 - VAE: 1.95104
# 38 /80 - total_train_loss: 5.61276 - reconst: 5.61815 - koopeman: 8.55093 - phase: 6.88327 - VAE: 1.39714
# 39 /80 - total_train_loss: 5.35116 - reconst: 5.41208 - koopeman: 8.69296 - phase: 6.48173 - VAE: 0.80044
# 40 /80 - total_train_loss: 5.10963 - reconst: 5.19696 - koopeman: 8.80486 - phase: 6.16427 - VAE: 0.24748
# 40 /80 - total_test_loss:  0.20981 - reconst: 0.21434 - koopeman: 0.36213 - phase: 0.25420 - VAE: 0.00726
# 41 /80 - total_train_loss: 4.91195 - reconst: 4.94648 - koopeman: 8.61604 - phase: 5.89955 - VAE: 0.17587
# 42 /80 - total_train_loss: 4.73220 - reconst: 4.71322 - koopeman: 8.37911 - phase: 5.64261 - VAE: 0.19929
# 43 /80 - total_train_loss: 4.56048 - reconst: 4.50003 - koopeman: 8.22314 - phase: 5.39098 - VAE: 0.14505
# 44 /80 - total_train_loss: 4.39871 - reconst: 4.28448 - koopeman: 8.04378 - phase: 5.15592 - VAE: 0.14331
# 45 /80 - total_train_loss: 4.24611 - reconst: 4.07716 - koopeman: 7.87827 - phase: 4.92771 - VAE: 0.14958
# 46 /80 - total_train_loss: 4.10088 - reconst: 3.87290 - koopeman: 7.72244 - phase: 4.71292 - VAE: 0.16038
# 47 /80 - total_train_loss: 3.96890 - reconst: 3.68167 - koopeman: 7.60690 - phase: 4.50111 - VAE: 0.16798
# 48 /80 - total_train_loss: 3.83597 - reconst: 3.49408 - koopeman: 7.45062 - phase: 4.30045 - VAE: 0.19641
# 49 /80 - total_train_loss: 3.71122 - reconst: 3.32253 - koopeman: 7.35480 - phase: 4.10435 - VAE: 0.17424
# 50 /80 - total_train_loss: 3.59573 - reconst: 3.15407 - koopeman: 7.22305 - phase: 3.92691 - VAE: 0.20506
# 50 /80 - total_test_loss:  0.14836 - reconst: 0.12773 - koopeman: 0.29916 - phase: 0.15859 - VAE: 0.01387
# 51 /80 - total_train_loss: 3.48095 - reconst: 3.00948 - koopeman: 7.14991 - phase: 3.74598 - VAE: 0.15314
# 52 /80 - total_train_loss: 3.38108 - reconst: 2.87007 - koopeman: 7.06449 - phase: 3.58483 - VAE: 0.15094
# 53 /80 - total_train_loss: 3.29148 - reconst: 2.74282 - koopeman: 6.96452 - phase: 3.43715 - VAE: 0.17818
# 54 /80 - total_train_loss: 3.20464 - reconst: 2.63316 - koopeman: 6.88109 - phase: 3.29315 - VAE: 0.17443
# 55 /80 - total_train_loss: 3.12354 - reconst: 2.52678 - koopeman: 6.76890 - phase: 3.17288 - VAE: 0.19610
# 56 /80 - total_train_loss: 3.04529 - reconst: 2.44307 - koopeman: 6.71665 - phase: 3.04576 - VAE: 0.14776
# 57 /80 - total_train_loss: 2.97721 - reconst: 2.35814 - koopeman: 6.65214 - phase: 2.94239 - VAE: 0.13305
# 58 /80 - total_train_loss: 2.91411 - reconst: 2.28046 - koopeman: 6.54644 - phase: 2.84706 - VAE: 0.16354
# 59 /80 - total_train_loss: 2.85124 - reconst: 2.21259 - koopeman: 6.49089 - phase: 2.75489 - VAE: 0.12906
# 60 /80 - total_train_loss: 2.80642 - reconst: 2.14520 - koopeman: 6.42218 - phase: 2.67602 - VAE: 0.17118
# 60 /80 - total_test_loss:  0.11446 - reconst: 0.08670 - koopeman: 0.26580 - phase: 0.10980 - VAE: 0.00347
# 61 /80 - total_train_loss: 2.75411 - reconst: 2.08378 - koopeman: 6.32652 - phase: 2.60060 - VAE: 0.19707
# 62 /80 - total_train_loss: 2.70896 - reconst: 2.02717 - koopeman: 6.26818 - phase: 2.52664 - VAE: 0.20863
# 63 /80 - total_train_loss: 2.65364 - reconst: 1.96915 - koopeman: 6.20916 - phase: 2.46385 - VAE: 0.16798
# 64 /80 - total_train_loss: 2.60425 - reconst: 1.91642 - koopeman: 6.15673 - phase: 2.39830 - VAE: 0.14206
# 65 /80 - total_train_loss: 2.56225 - reconst: 1.85869 - koopeman: 6.07964 - phase: 2.34597 - VAE: 0.16570
# 66 /80 - total_train_loss: 2.52145 - reconst: 1.81031 - koopeman: 6.03496 - phase: 2.28526 - VAE: 0.15846
# 67 /80 - total_train_loss: 2.49128 - reconst: 1.75601 - koopeman: 5.93544 - phase: 2.23658 - VAE: 0.24716
# 68 /80 - total_train_loss: 2.45063 - reconst: 1.70916 - koopeman: 5.91046 - phase: 2.18207 - VAE: 0.21268
# 69 /80 - total_train_loss: 2.40174 - reconst: 1.66254 - koopeman: 5.88422 - phase: 2.12884 - VAE: 0.14258
# 70 /80 - total_train_loss: 2.36426 - reconst: 1.61134 - koopeman: 5.80874 - phase: 2.08362 - VAE: 0.16847
# 70 /80 - total_test_loss:  0.09806 - reconst: 0.06625 - koopeman: 0.24007 - phase: 0.08554 - VAE: 0.00946
# 71 /80 - total_train_loss: 2.32284 - reconst: 1.56230 - koopeman: 5.77378 - phase: 2.03673 - VAE: 0.13584
# 72 /80 - total_train_loss: 2.29049 - reconst: 1.51737 - koopeman: 5.71785 - phase: 1.98685 - VAE: 0.16080
# 73 /80 - total_train_loss: 2.25563 - reconst: 1.47157 - koopeman: 5.68494 - phase: 1.94213 - VAE: 0.14789
# 74 /80 - total_train_loss: 2.23185 - reconst: 1.42493 - koopeman: 5.64614 - phase: 1.89658 - VAE: 0.19031
# 75 /80 - total_train_loss: 2.19500 - reconst: 1.38324 - koopeman: 5.61040 - phase: 1.84860 - VAE: 0.16972
# 76 /80 - total_train_loss: 2.15369 - reconst: 1.33631 - koopeman: 5.53246 - phase: 1.80772 - VAE: 0.17182
# 77 /80 - total_train_loss: 2.12644 - reconst: 1.29545 - koopeman: 5.52797 - phase: 1.76040 - VAE: 0.15935
# 78 /80 - total_train_loss: 2.09421 - reconst: 1.25037 - koopeman: 5.47991 - phase: 1.71943 - VAE: 0.16824
# 79 /80 - total_train_loss: 2.06103 - reconst: 1.21026 - koopeman: 5.43233 - phase: 1.67436 - VAE: 0.17026
# ----------Parameter: alpha=0.5----------
# 0  /80 - total_train_loss: 29.75875 - reconst: 39.17004 - koopeman: 0.56895 - phase: 39.12427 - VAE: 21.34917
# 1  /80 - total_train_loss: 29.60777 - reconst: 39.03098 - koopeman: 0.59916 - phase: 39.04437 - VAE: 20.91015
# 2  /80 - total_train_loss: 29.46905 - reconst: 38.90160 - koopeman: 0.65633 - phase: 38.97590 - VAE: 20.47729
# 3  /80 - total_train_loss: 29.35654 - reconst: 38.76299 - koopeman: 0.75145 - phase: 38.91583 - VAE: 20.18297
# 4  /80 - total_train_loss: 29.23326 - reconst: 38.59822 - koopeman: 0.85646 - phase: 38.85910 - VAE: 19.88933
# 5  /80 - total_train_loss: 29.08146 - reconst: 38.37732 - koopeman: 0.97497 - phase: 38.80226 - VAE: 19.57954
# 6  /80 - total_train_loss: 28.87154 - reconst: 38.04580 - koopeman: 1.10976 - phase: 38.73641 - VAE: 19.24569
# 7  /80 - total_train_loss: 28.55270 - reconst: 37.50740 - koopeman: 1.26623 - phase: 38.64481 - VAE: 18.88296
# 8  /80 - total_train_loss: 28.02942 - reconst: 36.58679 - koopeman: 1.45557 - phase: 38.48987 - VAE: 18.47071
# 9  /80 - total_train_loss: 27.13682 - reconst: 34.98594 - koopeman: 1.70264 - phase: 38.19008 - VAE: 17.97040
# 10 /80 - total_train_loss: 25.68765 - reconst: 32.39239 - koopeman: 2.04839 - phase: 37.57566 - VAE: 17.32470
# 10 /80 - total_test_loss:  1.03032 - reconst: 1.27903 - koopeman: 0.09467 - phase: 1.54492 - VAE: 0.70522
# 11 /80 - total_train_loss: 23.62130 - reconst: 28.78590 - koopeman: 2.53882 - phase: 36.35369 - VAE: 16.47756
# 12 /80 - total_train_loss: 21.15095 - reconst: 24.69544 - koopeman: 3.20291 - phase: 34.19718 - VAE: 15.41931
# 13 /80 - total_train_loss: 18.76901 - reconst: 21.09107 - koopeman: 4.00334 - phase: 31.10196 - VAE: 14.23555
# 14 /80 - total_train_loss: 16.92388 - reconst: 18.65157 - koopeman: 4.80169 - phase: 27.68214 - VAE: 13.10472
# 15 /80 - total_train_loss: 15.68443 - reconst: 17.23180 - koopeman: 5.42912 - phase: 24.77681 - VAE: 12.20527
# 16 /80 - total_train_loss: 14.81132 - reconst: 16.23132 - koopeman: 5.82843 - phase: 22.74408 - VAE: 11.60148
# 17 /80 - total_train_loss: 14.03116 - reconst: 15.19084 - koopeman: 6.09481 - phase: 21.34970 - VAE: 11.16991
# 18 /80 - total_train_loss: 13.18295 - reconst: 13.90344 - koopeman: 6.34810 - phase: 20.23541 - VAE: 10.80391
# 19 /80 - total_train_loss: 12.20702 - reconst: 12.34596 - koopeman: 6.68237 - phase: 19.13181 - VAE: 10.39009
# 20 /80 - total_train_loss: 11.15450 - reconst: 10.68066 - koopeman: 7.12607 - phase: 17.87012 - VAE: 9.88882
# 20 /80 - total_test_loss:  0.44511 - reconst: 0.41459 - koopeman: 0.30824 - phase: 0.71892 - VAE: 0.39974
# 21 /80 - total_train_loss: 10.15319 - reconst: 9.19254 - koopeman: 7.63143 - phase: 16.39875 - VAE: 9.31130
# 22 /80 - total_train_loss: 9.30971 - reconst: 8.07355 - koopeman: 8.08974 - phase: 14.81044 - VAE: 8.73744
# 23 /80 - total_train_loss: 8.65068 - reconst: 7.31376 - koopeman: 8.41130 - phase: 13.29059 - VAE: 8.26089
# 24 /80 - total_train_loss: 8.14577 - reconst: 6.80383 - koopeman: 8.58108 - phase: 11.97921 - VAE: 7.90281
# 25 /80 - total_train_loss: 7.75143 - reconst: 6.44098 - koopeman: 8.62841 - phase: 10.90400 - VAE: 7.65323
# 26 /80 - total_train_loss: 7.43082 - reconst: 6.15765 - koopeman: 8.59724 - phase: 10.03555 - VAE: 7.47919
# 27 /80 - total_train_loss: 7.15686 - reconst: 5.91525 - koopeman: 8.51865 - phase: 9.32275 - VAE: 7.35398
# 28 /80 - total_train_loss: 6.91547 - reconst: 5.69754 - koopeman: 8.42147 - phase: 8.72253 - VAE: 7.25619
# 29 /80 - total_train_loss: 6.69623 - reconst: 5.49261 - koopeman: 8.31761 - phase: 8.20840 - VAE: 7.17353
# 30 /80 - total_train_loss: 6.49255 - reconst: 5.29507 - koopeman: 8.21282 - phase: 7.76245 - VAE: 7.09484
# 30 /80 - total_test_loss:  0.27053 - reconst: 0.22198 - koopeman: 0.33954 - phase: 0.32256 - VAE: 0.29511
# 31 /80 - total_train_loss: 6.30188 - reconst: 5.10566 - koopeman: 8.12103 - phase: 7.36041 - VAE: 7.01283
# 32 /80 - total_train_loss: 6.12093 - reconst: 4.92072 - koopeman: 8.03697 - phase: 7.00240 - VAE: 6.92402
# 33 /80 - total_train_loss: 5.94850 - reconst: 4.74229 - koopeman: 7.97034 - phase: 6.67335 - VAE: 6.82045
# 34 /80 - total_train_loss: 5.78347 - reconst: 4.56667 - koopeman: 7.91051 - phase: 6.37601 - VAE: 6.71428
# 35 /80 - total_train_loss: 5.62521 - reconst: 4.39756 - koopeman: 7.86918 - phase: 6.09836 - VAE: 6.59103
# 36 /80 - total_train_loss: 5.47255 - reconst: 4.23150 - koopeman: 7.83205 - phase: 5.84579 - VAE: 6.46296
# 37 /80 - total_train_loss: 5.32429 - reconst: 4.07333 - koopeman: 7.81478 - phase: 5.60351 - VAE: 6.30748
# 38 /80 - total_train_loss: 5.18235 - reconst: 3.91802 - koopeman: 7.79951 - phase: 5.38300 - VAE: 6.15754
# 39 /80 - total_train_loss: 5.04556 - reconst: 3.77006 - koopeman: 7.79999 - phase: 5.17355 - VAE: 5.98967
# 40 /80 - total_train_loss: 4.91228 - reconst: 3.62816 - koopeman: 7.80852 - phase: 4.97620 - VAE: 5.80448
# 40 /80 - total_test_loss:  0.20401 - reconst: 0.15174 - koopeman: 0.32709 - phase: 0.20641 - VAE: 0.23535
# 41 /80 - total_train_loss: 4.78498 - reconst: 3.49418 - koopeman: 7.82413 - phase: 4.78849 - VAE: 5.61473
# 42 /80 - total_train_loss: 4.66262 - reconst: 3.36530 - koopeman: 7.84753 - phase: 4.61468 - VAE: 5.41759
# 43 /80 - total_train_loss: 4.54418 - reconst: 3.24449 - koopeman: 7.87503 - phase: 4.45170 - VAE: 5.20485
# 44 /80 - total_train_loss: 4.43102 - reconst: 3.13268 - koopeman: 7.90738 - phase: 4.29623 - VAE: 4.98447
# 45 /80 - total_train_loss: 4.32478 - reconst: 3.02936 - koopeman: 7.94882 - phase: 4.15106 - VAE: 4.76071
# 46 /80 - total_train_loss: 4.22318 - reconst: 2.93356 - koopeman: 7.98705 - phase: 4.01588 - VAE: 4.53546
# 47 /80 - total_train_loss: 4.12613 - reconst: 2.84599 - koopeman: 8.03320 - phase: 3.89126 - VAE: 4.29436
# 48 /80 - total_train_loss: 4.03417 - reconst: 2.76656 - koopeman: 8.07715 - phase: 3.77475 - VAE: 4.05345
# 49 /80 - total_train_loss: 3.94653 - reconst: 2.69471 - koopeman: 8.12323 - phase: 3.66767 - VAE: 3.80411
# 50 /80 - total_train_loss: 3.86199 - reconst: 2.62795 - koopeman: 8.17404 - phase: 3.57033 - VAE: 3.54374
# 50 /80 - total_test_loss:  0.15966 - reconst: 0.10781 - koopeman: 0.34441 - phase: 0.14679 - VAE: 0.14334
# 51 /80 - total_train_loss: 3.78070 - reconst: 2.56658 - koopeman: 8.22680 - phase: 3.48145 - VAE: 3.27620
# 52 /80 - total_train_loss: 3.70487 - reconst: 2.50995 - koopeman: 8.28435 - phase: 3.40018 - VAE: 3.01486
# 53 /80 - total_train_loss: 3.62933 - reconst: 2.45715 - koopeman: 8.34187 - phase: 3.32417 - VAE: 2.73850
# 54 /80 - total_train_loss: 3.55504 - reconst: 2.40631 - koopeman: 8.41393 - phase: 3.25612 - VAE: 2.44126
# 55 /80 - total_train_loss: 3.47875 - reconst: 2.35744 - koopeman: 8.48456 - phase: 3.19304 - VAE: 2.12258
# 56 /80 - total_train_loss: 3.40593 - reconst: 2.31017 - koopeman: 8.57058 - phase: 3.13410 - VAE: 1.80036
# 57 /80 - total_train_loss: 3.33225 - reconst: 2.26160 - koopeman: 8.66639 - phase: 3.08182 - VAE: 1.46051
# 58 /80 - total_train_loss: 3.25630 - reconst: 2.21484 - koopeman: 8.77561 - phase: 3.03150 - VAE: 1.08618
# 59 /80 - total_train_loss: 3.17981 - reconst: 2.16717 - koopeman: 8.89522 - phase: 2.98357 - VAE: 0.69855
# 60 /80 - total_train_loss: 3.10318 - reconst: 2.11793 - koopeman: 9.03357 - phase: 2.93982 - VAE: 0.29193
# 60 /80 - total_test_loss:  0.12812 - reconst: 0.08589 - koopeman: 0.38355 - phase: 0.12221 - VAE: 0.00526
# 61 /80 - total_train_loss: 3.03903 - reconst: 2.05638 - koopeman: 8.90915 - phase: 2.91885 - VAE: 0.23702
# 62 /80 - total_train_loss: 2.98013 - reconst: 2.00051 - koopeman: 8.75511 - phase: 2.87666 - VAE: 0.24748
# 63 /80 - total_train_loss: 2.91392 - reconst: 1.94515 - koopeman: 8.66775 - phase: 2.83120 - VAE: 0.14909
# 64 /80 - total_train_loss: 2.85206 - reconst: 1.88691 - koopeman: 8.53102 - phase: 2.78813 - VAE: 0.13249
# 65 /80 - total_train_loss: 2.79592 - reconst: 1.82919 - koopeman: 8.40960 - phase: 2.74185 - VAE: 0.13651
# 66 /80 - total_train_loss: 2.74370 - reconst: 1.76795 - koopeman: 8.22558 - phase: 2.70140 - VAE: 0.23138
# 67 /80 - total_train_loss: 2.68358 - reconst: 1.71375 - koopeman: 8.15577 - phase: 2.64136 - VAE: 0.16311
# 68 /80 - total_train_loss: 2.62518 - reconst: 1.65113 - koopeman: 8.04982 - phase: 2.59471 - VAE: 0.15317
# 69 /80 - total_train_loss: 2.56807 - reconst: 1.59124 - koopeman: 7.94645 - phase: 2.54297 - VAE: 0.14525
# 70 /80 - total_train_loss: 2.51286 - reconst: 1.52829 - koopeman: 7.85906 - phase: 2.49191 - VAE: 0.14133
# 70 /80 - total_test_loss:  0.10379 - reconst: 0.06231 - koopeman: 0.32530 - phase: 0.10229 - VAE: 0.00822
# 71 /80 - total_train_loss: 2.45583 - reconst: 1.46600 - koopeman: 7.78316 - phase: 2.43903 - VAE: 0.11476
# 72 /80 - total_train_loss: 2.40366 - reconst: 1.40231 - koopeman: 7.66900 - phase: 2.38819 - VAE: 0.15786
# 73 /80 - total_train_loss: 2.35049 - reconst: 1.33945 - koopeman: 7.59447 - phase: 2.33209 - VAE: 0.15800
# 74 /80 - total_train_loss: 2.30226 - reconst: 1.27549 - koopeman: 7.51294 - phase: 2.27963 - VAE: 0.19449
# 75 /80 - total_train_loss: 2.24827 - reconst: 1.21093 - koopeman: 7.39693 - phase: 2.22637 - VAE: 0.23355
# 76 /80 - total_train_loss: 2.18652 - reconst: 1.14711 - koopeman: 7.35624 - phase: 2.16999 - VAE: 0.15155
# 77 /80 - total_train_loss: 2.13870 - reconst: 1.08441 - koopeman: 7.31384 - phase: 2.11323 - VAE: 0.15189
# 78 /80 - total_train_loss: 2.08787 - reconst: 1.02088 - koopeman: 7.22111 - phase: 2.06374 - VAE: 0.17971
# 79 /80 - total_train_loss: 2.03794 - reconst: 0.96051 - koopeman: 7.14247 - phase: 2.00536 - VAE: 0.19827
# ----------Parameter: alpha=0.8----------
# 0  /80 - total_train_loss: 35.40260 - reconst: 39.16217 - koopeman: 0.56647 - phase: 39.12566 - VAE: 21.40083
# 1  /80 - total_train_loss: 35.25530 - reconst: 39.01014 - koopeman: 0.59054 - phase: 39.05008 - VAE: 21.06712
# 2  /80 - total_train_loss: 35.11397 - reconst: 38.86826 - koopeman: 0.63471 - phase: 38.98878 - VAE: 20.66704
# 3  /80 - total_train_loss: 34.96899 - reconst: 38.71166 - koopeman: 0.71029 - phase: 38.93979 - VAE: 20.34475
# 4  /80 - total_train_loss: 34.79532 - reconst: 38.51053 - koopeman: 0.81144 - phase: 38.90208 - VAE: 20.08989
# 5  /80 - total_train_loss: 34.54711 - reconst: 38.21488 - koopeman: 0.93275 - phase: 38.87775 - VAE: 19.81756
# 6  /80 - total_train_loss: 34.14618 - reconst: 37.72777 - koopeman: 1.08829 - phase: 38.86701 - VAE: 19.50417
# 7  /80 - total_train_loss: 33.45333 - reconst: 36.87612 - koopeman: 1.30396 - phase: 38.87170 - VAE: 19.11078
# 8  /80 - total_train_loss: 32.23665 - reconst: 35.37142 - koopeman: 1.62473 - phase: 38.88881 - VAE: 18.57914
# 9  /80 - total_train_loss: 30.25988 - reconst: 32.92099 - koopeman: 2.11796 - phase: 38.88634 - VAE: 17.84199
# 10 /80 - total_train_loss: 27.51883 - reconst: 29.52651 - koopeman: 2.85125 - phase: 38.75257 - VAE: 16.86049
# 10 /80 - total_test_loss:  1.08041 - reconst: 1.14850 - koopeman: 0.13853 - phase: 1.60764 - VAE: 0.67785
# 11 /80 - total_train_loss: 24.38942 - reconst: 25.67207 - koopeman: 3.84760 - phase: 38.27094 - VAE: 15.65786
# 12 /80 - total_train_loss: 21.47851 - reconst: 22.13372 - koopeman: 5.02703 - phase: 37.19531 - VAE: 14.35064
# 13 /80 - total_train_loss: 19.22492 - reconst: 19.46617 - koopeman: 6.17832 - phase: 35.45882 - VAE: 13.14265
# 14 /80 - total_train_loss: 17.61072 - reconst: 17.62788 - koopeman: 7.07461 - phase: 33.34648 - VAE: 12.20516
# 15 /80 - total_train_loss: 16.31460 - reconst: 16.17940 - koopeman: 7.66764 - phase: 31.34118 - VAE: 11.55738
# 16 /80 - total_train_loss: 15.04438 - reconst: 14.73140 - koopeman: 8.10690 - phase: 29.70808 - VAE: 11.07399
# 17 /80 - total_train_loss: 13.67389 - reconst: 13.12654 - koopeman: 8.57594 - phase: 28.40432 - VAE: 10.60961
# 18 /80 - total_train_loss: 12.26064 - reconst: 11.45055 - koopeman: 9.17600 - phase: 27.25150 - VAE: 10.07543
# 19 /80 - total_train_loss: 10.95972 - reconst: 9.91798 - koopeman: 9.88396 - phase: 26.03049 - VAE: 9.46553
# 20 /80 - total_train_loss: 9.88453 - reconst: 8.68813 - koopeman: 10.57360 - phase: 24.57683 - VAE: 8.85990
# 20 /80 - total_test_loss:  0.39584 - reconst: 0.34441 - koopeman: 0.45480 - phase: 0.99409 - VAE: 0.35589
# 21 /80 - total_train_loss: 9.05278 - reconst: 7.78814 - koopeman: 11.11944 - phase: 22.88341 - VAE: 8.33117
# 22 /80 - total_train_loss: 8.42116 - reconst: 7.15161 - koopeman: 11.46429 - phase: 21.10530 - VAE: 7.92845
# 23 /80 - total_train_loss: 7.93056 - reconst: 6.68966 - koopeman: 11.62772 - phase: 19.40917 - VAE: 7.64551
# 24 /80 - total_train_loss: 7.53146 - reconst: 6.32987 - koopeman: 11.65809 - phase: 17.89566 - VAE: 7.45974
# 25 /80 - total_train_loss: 7.18910 - reconst: 6.02771 - koopeman: 11.59994 - phase: 16.57169 - VAE: 7.33230
# 26 /80 - total_train_loss: 6.88356 - reconst: 5.75606 - koopeman: 11.49769 - phase: 15.42205 - VAE: 7.26083
# 27 /80 - total_train_loss: 6.60039 - reconst: 5.50173 - koopeman: 11.37462 - phase: 14.40781 - VAE: 7.20264
# 28 /80 - total_train_loss: 6.33335 - reconst: 5.25613 - koopeman: 11.24539 - phase: 13.51735 - VAE: 7.16393
# 29 /80 - total_train_loss: 6.07785 - reconst: 5.01728 - koopeman: 11.12314 - phase: 12.71366 - VAE: 7.12355
# 30 /80 - total_train_loss: 5.83230 - reconst: 4.78326 - koopeman: 11.01348 - phase: 11.98278 - VAE: 7.08912
# 30 /80 - total_test_loss:  0.24247 - reconst: 0.19935 - koopeman: 0.45765 - phase: 0.49293 - VAE: 0.29417
# 31 /80 - total_train_loss: 5.59425 - reconst: 4.55371 - koopeman: 10.91841 - phase: 11.30978 - VAE: 7.04105
# 32 /80 - total_train_loss: 5.36469 - reconst: 4.32910 - koopeman: 10.83678 - phase: 10.69036 - VAE: 6.99399
# 33 /80 - total_train_loss: 5.14301 - reconst: 4.11098 - koopeman: 10.77298 - phase: 10.10950 - VAE: 6.93087
# 34 /80 - total_train_loss: 4.93005 - reconst: 3.89945 - koopeman: 10.71948 - phase: 9.56998 - VAE: 6.86785
# 35 /80 - total_train_loss: 4.72711 - reconst: 3.69733 - koopeman: 10.67708 - phase: 9.06198 - VAE: 6.79964
# 36 /80 - total_train_loss: 4.53510 - reconst: 3.50537 - koopeman: 10.63909 - phase: 8.59100 - VAE: 6.73193
# 37 /80 - total_train_loss: 4.35488 - reconst: 3.32597 - koopeman: 10.60878 - phase: 8.14641 - VAE: 6.65637
# 38 /80 - total_train_loss: 4.18793 - reconst: 3.15969 - koopeman: 10.57379 - phase: 7.73579 - VAE: 6.59315
# 39 /80 - total_train_loss: 4.03509 - reconst: 3.00875 - koopeman: 10.53513 - phase: 7.35592 - VAE: 6.53038
# 40 /80 - total_train_loss: 3.89623 - reconst: 2.87261 - koopeman: 10.48891 - phase: 7.00251 - VAE: 6.48077
# 40 /80 - total_test_loss:  0.16157 - reconst: 0.11941 - koopeman: 0.43723 - phase: 0.28676 - VAE: 0.26662
# 41 /80 - total_train_loss: 3.77124 - reconst: 2.75188 - koopeman: 10.43319 - phase: 6.67629 - VAE: 6.43663
# 42 /80 - total_train_loss: 3.65883 - reconst: 2.64420 - koopeman: 10.35946 - phase: 6.38318 - VAE: 6.40941
# 43 /80 - total_train_loss: 3.55828 - reconst: 2.54906 - koopeman: 10.26958 - phase: 6.11590 - VAE: 6.40006
# 44 /80 - total_train_loss: 3.46718 - reconst: 2.46420 - koopeman: 10.17098 - phase: 5.86962 - VAE: 6.39682
# 45 /80 - total_train_loss: 3.38470 - reconst: 2.38764 - koopeman: 10.06156 - phase: 5.64602 - VAE: 6.41125
# 46 /80 - total_train_loss: 3.30879 - reconst: 2.31750 - koopeman: 9.94264 - phase: 5.44025 - VAE: 6.43898
# 47 /80 - total_train_loss: 3.23775 - reconst: 2.25178 - koopeman: 9.81757 - phase: 5.25495 - VAE: 6.47228
# 48 /80 - total_train_loss: 3.17082 - reconst: 2.18991 - koopeman: 9.68926 - phase: 5.08130 - VAE: 6.51273
# 49 /80 - total_train_loss: 3.10622 - reconst: 2.13007 - koopeman: 9.56309 - phase: 4.92183 - VAE: 6.54754
# 50 /80 - total_train_loss: 3.04460 - reconst: 2.07194 - koopeman: 9.43616 - phase: 4.77456 - VAE: 6.59494
# 50 /80 - total_test_loss:  0.12543 - reconst: 0.08490 - koopeman: 0.39257 - phase: 0.19627 - VAE: 0.27379
# 51 /80 - total_train_loss: 2.98447 - reconst: 2.01484 - koopeman: 9.31590 - phase: 4.63486 - VAE: 6.63821
# 52 /80 - total_train_loss: 2.92586 - reconst: 1.95853 - koopeman: 9.20047 - phase: 4.50365 - VAE: 6.68136
# 53 /80 - total_train_loss: 2.86768 - reconst: 1.90184 - koopeman: 9.09590 - phase: 4.38029 - VAE: 6.71692
# 54 /80 - total_train_loss: 2.80982 - reconst: 1.84559 - koopeman: 8.99749 - phase: 4.26187 - VAE: 6.74086
# 55 /80 - total_train_loss: 2.75258 - reconst: 1.78864 - koopeman: 8.90819 - phase: 4.14905 - VAE: 6.76781
# 56 /80 - total_train_loss: 2.69525 - reconst: 1.73100 - koopeman: 8.83149 - phase: 4.04198 - VAE: 6.78331
# 57 /80 - total_train_loss: 2.63779 - reconst: 1.67227 - koopeman: 8.76042 - phase: 3.94159 - VAE: 6.79758
# 58 /80 - total_train_loss: 2.57960 - reconst: 1.61254 - koopeman: 8.70765 - phase: 3.84393 - VAE: 6.79192
# 59 /80 - total_train_loss: 2.52090 - reconst: 1.55177 - koopeman: 8.65799 - phase: 3.74753 - VAE: 6.78662
# 60 /80 - total_train_loss: 2.46123 - reconst: 1.48926 - koopeman: 8.62282 - phase: 3.65769 - VAE: 6.76684
# 60 /80 - total_test_loss:  0.10082 - reconst: 0.06006 - koopeman: 0.36242 - phase: 0.15188 - VAE: 0.27723
# 61 /80 - total_train_loss: 2.40095 - reconst: 1.42504 - koopeman: 8.60171 - phase: 3.57184 - VAE: 6.74016
# 62 /80 - total_train_loss: 2.33957 - reconst: 1.35948 - koopeman: 8.59048 - phase: 3.48539 - VAE: 6.70387
# 63 /80 - total_train_loss: 2.27692 - reconst: 1.29202 - koopeman: 8.59293 - phase: 3.40447 - VAE: 6.65220
# 64 /80 - total_train_loss: 2.21309 - reconst: 1.22292 - koopeman: 8.60844 - phase: 3.32466 - VAE: 6.58824
# 65 /80 - total_train_loss: 2.14835 - reconst: 1.15239 - koopeman: 8.63051 - phase: 3.24818 - VAE: 6.51779
# 66 /80 - total_train_loss: 2.08263 - reconst: 1.08064 - koopeman: 8.66877 - phase: 3.17351 - VAE: 6.42957
# 67 /80 - total_train_loss: 2.01688 - reconst: 1.00862 - koopeman: 8.71477 - phase: 3.09757 - VAE: 6.33748
# 68 /80 - total_train_loss: 1.95067 - reconst: 0.93634 - koopeman: 8.77367 - phase: 3.02464 - VAE: 6.22566
# 69 /80 - total_train_loss: 1.88518 - reconst: 0.86484 - koopeman: 8.83892 - phase: 2.95133 - VAE: 6.10927
# 70 /80 - total_train_loss: 1.82041 - reconst: 0.79479 - koopeman: 8.90918 - phase: 2.87829 - VAE: 5.98121
# 70 /80 - total_test_loss:  0.07448 - reconst: 0.03163 - koopeman: 0.37320 - phase: 0.11828 - VAE: 0.24625
# 71 /80 - total_train_loss: 1.75745 - reconst: 0.72707 - koopeman: 8.98433 - phase: 2.80305 - VAE: 5.84951
# 72 /80 - total_train_loss: 1.69639 - reconst: 0.66242 - koopeman: 9.06006 - phase: 2.72981 - VAE: 5.70691
# 73 /80 - total_train_loss: 1.63842 - reconst: 0.60155 - koopeman: 9.13655 - phase: 2.65417 - VAE: 5.56701
# 74 /80 - total_train_loss: 1.58302 - reconst: 0.54416 - koopeman: 9.20646 - phase: 2.58392 - VAE: 5.42500
# 75 /80 - total_train_loss: 1.53133 - reconst: 0.49214 - koopeman: 9.27236 - phase: 2.50601 - VAE: 5.28587
# 76 /80 - total_train_loss: 1.48299 - reconst: 0.44379 - koopeman: 9.33362 - phase: 2.43719 - VAE: 5.14861
# 77 /80 - total_train_loss: 1.43776 - reconst: 0.40067 - koopeman: 9.38281 - phase: 2.36468 - VAE: 5.01083
# 78 /80 - total_train_loss: 1.39584 - reconst: 0.36146 - koopeman: 9.42707 - phase: 2.29809 - VAE: 4.87487
# 79 /80 - total_train_loss: 1.35738 - reconst: 0.32695 - koopeman: 9.46167 - phase: 2.22952 - VAE: 4.74615
# ----------Parameter: alpha=1.0----------
# 0  /80 - total_train_loss: 39.15908 - reconst: 39.15908 - koopeman: 0.56067 - phase: 39.12612 - VAE: 21.54646
# 1  /80 - total_train_loss: 39.00091 - reconst: 39.00091 - koopeman: 0.56951 - phase: 39.05120 - VAE: 21.54173
# 2  /80 - total_train_loss: 38.85118 - reconst: 38.85118 - koopeman: 0.59536 - phase: 38.99106 - VAE: 21.48985
# 3  /80 - total_train_loss: 38.68080 - reconst: 38.68080 - koopeman: 0.64025 - phase: 38.94558 - VAE: 21.38523
# 4  /80 - total_train_loss: 38.44879 - reconst: 38.44879 - koopeman: 0.70953 - phase: 38.91475 - VAE: 21.21636
# 5  /80 - total_train_loss: 38.08482 - reconst: 38.08482 - koopeman: 0.81468 - phase: 38.90192 - VAE: 20.96225
# 6  /80 - total_train_loss: 37.45437 - reconst: 37.45437 - koopeman: 0.97543 - phase: 38.90931 - VAE: 20.59548
# 7  /80 - total_train_loss: 36.31680 - reconst: 36.31680 - koopeman: 1.23161 - phase: 38.94510 - VAE: 20.07210
# 8  /80 - total_train_loss: 34.32375 - reconst: 34.32375 - koopeman: 1.66256 - phase: 39.02077 - VAE: 19.32433
# 9  /80 - total_train_loss: 31.25338 - reconst: 31.25338 - koopeman: 2.39834 - phase: 39.15075 - VAE: 18.28093
# 10 /80 - total_train_loss: 27.40324 - reconst: 27.40324 - koopeman: 3.56937 - phase: 39.35579 - VAE: 16.94283
# 10 /80 - total_test_loss:  1.05688 - reconst: 1.05688 - koopeman: 0.18109 - phase: 1.64581 - VAE: 0.67366
# 11 /80 - total_train_loss: 23.64286 - reconst: 23.64286 - koopeman: 5.17362 - phase: 39.66026 - VAE: 15.43932
# 12 /80 - total_train_loss: 20.81754 - reconst: 20.81754 - koopeman: 6.93744 - phase: 40.08564 - VAE: 14.01467
# 13 /80 - total_train_loss: 19.09582 - reconst: 19.09582 - koopeman: 8.40406 - phase: 40.60440 - VAE: 12.91352
# 14 /80 - total_train_loss: 18.02702 - reconst: 18.02702 - koopeman: 9.32480 - phase: 41.14301 - VAE: 12.21591
# 15 /80 - total_train_loss: 17.13811 - reconst: 17.13811 - koopeman: 9.82089 - phase: 41.64954 - VAE: 11.82076
# 16 /80 - total_train_loss: 16.15842 - reconst: 16.15842 - koopeman: 10.13146 - phase: 42.14554 - VAE: 11.57640
# 17 /80 - total_train_loss: 14.94215 - reconst: 14.94215 - koopeman: 10.43123 - phase: 42.68877 - VAE: 11.36308
# 18 /80 - total_train_loss: 13.44608 - reconst: 13.44608 - koopeman: 10.86676 - phase: 43.32366 - VAE: 11.07608
# 19 /80 - total_train_loss: 11.76594 - reconst: 11.76594 - koopeman: 11.55734 - phase: 44.11537 - VAE: 10.63850
# 20 /80 - total_train_loss: 10.12884 - reconst: 10.12884 - koopeman: 12.53989 - phase: 45.11282 - VAE: 10.03173
# 20 /80 - total_test_loss:  0.39418 - reconst: 0.39418 - koopeman: 0.54914 - phase: 1.91423 - VAE: 0.40139
# 21 /80 - total_train_loss: 8.76609 - reconst: 8.76609 - koopeman: 13.71896 - phase: 46.29208 - VAE: 9.32409
# 22 /80 - total_train_loss: 7.76672 - reconst: 7.76672 - koopeman: 14.89692 - phase: 47.49693 - VAE: 8.63050
# 23 /80 - total_train_loss: 7.07544 - reconst: 7.07544 - koopeman: 15.89482 - phase: 48.52419 - VAE: 8.04196
# 24 /80 - total_train_loss: 6.58812 - reconst: 6.58812 - koopeman: 16.64158 - phase: 49.27806 - VAE: 7.59073
# 25 /80 - total_train_loss: 6.21778 - reconst: 6.21778 - koopeman: 17.15229 - phase: 49.74771 - VAE: 7.26404
# 26 /80 - total_train_loss: 5.90942 - reconst: 5.90942 - koopeman: 17.50275 - phase: 50.04721 - VAE: 7.02734
# 27 /80 - total_train_loss: 5.63205 - reconst: 5.63205 - koopeman: 17.74003 - phase: 50.19993 - VAE: 6.85250
# 28 /80 - total_train_loss: 5.37039 - reconst: 5.37039 - koopeman: 17.91188 - phase: 50.28149 - VAE: 6.71617
# 29 /80 - total_train_loss: 5.11737 - reconst: 5.11737 - koopeman: 18.05019 - phase: 50.30728 - VAE: 6.60438
# 30 /80 - total_train_loss: 4.86973 - reconst: 4.86973 - koopeman: 18.18355 - phase: 50.30364 - VAE: 6.51549
# 30 /80 - total_test_loss:  0.20278 - reconst: 0.20278 - koopeman: 0.76367 - phase: 2.11091 - VAE: 0.26912
# 31 /80 - total_train_loss: 4.62615 - reconst: 4.62615 - koopeman: 18.31665 - phase: 50.27920 - VAE: 6.43236
# 32 /80 - total_train_loss: 4.38737 - reconst: 4.38737 - koopeman: 18.46282 - phase: 50.24675 - VAE: 6.34672
# 33 /80 - total_train_loss: 4.15433 - reconst: 4.15433 - koopeman: 18.63077 - phase: 50.21055 - VAE: 6.25069
# 34 /80 - total_train_loss: 3.92814 - reconst: 3.92814 - koopeman: 18.81273 - phase: 50.15601 - VAE: 6.14681
# 35 /80 - total_train_loss: 3.71130 - reconst: 3.71130 - koopeman: 19.01020 - phase: 50.10153 - VAE: 6.03510
# 36 /80 - total_train_loss: 3.50578 - reconst: 3.50578 - koopeman: 19.21802 - phase: 50.05000 - VAE: 5.91927
# 37 /80 - total_train_loss: 3.31387 - reconst: 3.31387 - koopeman: 19.43479 - phase: 49.98400 - VAE: 5.79813
# 38 /80 - total_train_loss: 3.13715 - reconst: 3.13715 - koopeman: 19.64353 - phase: 49.91969 - VAE: 5.68145
# 39 /80 - total_train_loss: 2.97807 - reconst: 2.97807 - koopeman: 19.84318 - phase: 49.85151 - VAE: 5.56895
# 40 /80 - total_train_loss: 2.83597 - reconst: 2.83597 - koopeman: 20.02039 - phase: 49.77106 - VAE: 5.46745
# 40 /80 - total_test_loss:  0.11790 - reconst: 0.11790 - koopeman: 0.83827 - phase: 2.06020 - VAE: 0.22479
# 41 /80 - total_train_loss: 2.71138 - reconst: 2.71138 - koopeman: 20.17482 - phase: 49.70664 - VAE: 5.37832
# 42 /80 - total_train_loss: 2.60225 - reconst: 2.60225 - koopeman: 20.27865 - phase: 49.61721 - VAE: 5.31186
# 43 /80 - total_train_loss: 2.50704 - reconst: 2.50704 - koopeman: 20.34092 - phase: 49.53011 - VAE: 5.26632
# 44 /80 - total_train_loss: 2.42313 - reconst: 2.42313 - koopeman: 20.36756 - phase: 49.44341 - VAE: 5.23909
# 45 /80 - total_train_loss: 2.34810 - reconst: 2.34810 - koopeman: 20.35554 - phase: 49.34973 - VAE: 5.23770
# 46 /80 - total_train_loss: 2.27969 - reconst: 2.27969 - koopeman: 20.31555 - phase: 49.27613 - VAE: 5.26569
# 47 /80 - total_train_loss: 2.21614 - reconst: 2.21614 - koopeman: 20.23544 - phase: 49.17541 - VAE: 5.32029
# 48 /80 - total_train_loss: 2.15598 - reconst: 2.15598 - koopeman: 20.14231 - phase: 49.10655 - VAE: 5.38547
# 49 /80 - total_train_loss: 2.09817 - reconst: 2.09817 - koopeman: 20.03230 - phase: 49.01994 - VAE: 5.46110
# 50 /80 - total_train_loss: 2.04199 - reconst: 2.04199 - koopeman: 19.90660 - phase: 48.93953 - VAE: 5.54595
# 50 /80 - total_test_loss:  0.08378 - reconst: 0.08378 - koopeman: 0.82909 - phase: 2.04258 - VAE: 0.23293
# 51 /80 - total_train_loss: 1.98687 - reconst: 1.98687 - koopeman: 19.77933 - phase: 48.86670 - VAE: 5.63164
# 52 /80 - total_train_loss: 1.93259 - reconst: 1.93259 - koopeman: 19.65377 - phase: 48.79281 - VAE: 5.71730
# 53 /80 - total_train_loss: 1.87862 - reconst: 1.87862 - koopeman: 19.52330 - phase: 48.73210 - VAE: 5.80595
# 54 /80 - total_train_loss: 1.82492 - reconst: 1.82492 - koopeman: 19.40536 - phase: 48.66006 - VAE: 5.88888
# 55 /80 - total_train_loss: 1.77117 - reconst: 1.77117 - koopeman: 19.28739 - phase: 48.59903 - VAE: 5.96999
# 56 /80 - total_train_loss: 1.71728 - reconst: 1.71728 - koopeman: 19.18413 - phase: 48.54010 - VAE: 6.04669
# 57 /80 - total_train_loss: 1.66308 - reconst: 1.66308 - koopeman: 19.07542 - phase: 48.47825 - VAE: 6.12503
# 58 /80 - total_train_loss: 1.60833 - reconst: 1.60833 - koopeman: 18.99725 - phase: 48.41527 - VAE: 6.18980
# 59 /80 - total_train_loss: 1.55292 - reconst: 1.55292 - koopeman: 18.91639 - phase: 48.36688 - VAE: 6.25331
# 60 /80 - total_train_loss: 1.49676 - reconst: 1.49676 - koopeman: 18.85576 - phase: 48.30416 - VAE: 6.31008
# 60 /80 - total_test_loss:  0.06060 - reconst: 0.06060 - koopeman: 0.79041 - phase: 2.02002 - VAE: 0.26097
# 61 /80 - total_train_loss: 1.43963 - reconst: 1.43963 - koopeman: 18.81231 - phase: 48.25286 - VAE: 6.35807
# 62 /80 - total_train_loss: 1.38144 - reconst: 1.38144 - koopeman: 18.78688 - phase: 48.20118 - VAE: 6.39757
# 63 /80 - total_train_loss: 1.32205 - reconst: 1.32205 - koopeman: 18.78111 - phase: 48.13623 - VAE: 6.42720
# 64 /80 - total_train_loss: 1.26130 - reconst: 1.26130 - koopeman: 18.80012 - phase: 48.09011 - VAE: 6.44669
# 65 /80 - total_train_loss: 1.19926 - reconst: 1.19926 - koopeman: 18.83361 - phase: 48.02522 - VAE: 6.45887
# 66 /80 - total_train_loss: 1.13577 - reconst: 1.13577 - koopeman: 18.90187 - phase: 47.96673 - VAE: 6.45598
# 67 /80 - total_train_loss: 1.07099 - reconst: 1.07099 - koopeman: 18.99877 - phase: 47.91562 - VAE: 6.43978
# 68 /80 - total_train_loss: 1.00499 - reconst: 1.00499 - koopeman: 19.13495 - phase: 47.84998 - VAE: 6.40554
# 69 /80 - total_train_loss: 0.93797 - reconst: 0.93797 - koopeman: 19.29844 - phase: 47.79170 - VAE: 6.35844
# 70 /80 - total_train_loss: 0.87040 - reconst: 0.87040 - koopeman: 19.50189 - phase: 47.73002 - VAE: 6.29666
# 70 /80 - total_test_loss:  0.03477 - reconst: 0.03477 - koopeman: 0.81864 - phase: 1.99224 - VAE: 0.26056
# 71 /80 - total_train_loss: 0.80251 - reconst: 0.80251 - koopeman: 19.74603 - phase: 47.67872 - VAE: 6.21380
# 72 /80 - total_train_loss: 0.73528 - reconst: 0.73528 - koopeman: 20.02613 - phase: 47.61952 - VAE: 6.11645
# 73 /80 - total_train_loss: 0.66926 - reconst: 0.66926 - koopeman: 20.35075 - phase: 47.56754 - VAE: 5.99985
# 74 /80 - total_train_loss: 0.60537 - reconst: 0.60537 - koopeman: 20.69597 - phase: 47.51221 - VAE: 5.87570
# 75 /80 - total_train_loss: 0.54436 - reconst: 0.54436 - koopeman: 21.08695 - phase: 47.47856 - VAE: 5.73062
# 76 /80 - total_train_loss: 0.48698 - reconst: 0.48698 - koopeman: 21.49445 - phase: 47.44336 - VAE: 5.58120
# 77 /80 - total_train_loss: 0.43386 - reconst: 0.43386 - koopeman: 21.91796 - phase: 47.42299 - VAE: 5.42429
# 78 /80 - total_train_loss: 0.38545 - reconst: 0.38545 - koopeman: 22.34902 - phase: 47.40468 - VAE: 5.26536
# 79 /80 - total_train_loss: 0.34202 - reconst: 0.34202 - koopeman: 22.79167 - phase: 47.41570 - VAE: 5.10226
# ----------Parameter: beta=0.1----------
# 0  /80 - total_train_loss: 29.94466 - reconst: 39.18137 - koopeman: 0.58277 - phase: 39.12201 - VAE: 21.31789
# 1  /80 - total_train_loss: 29.73912 - reconst: 39.05990 - koopeman: 0.64093 - phase: 39.03542 - VAE: 20.82142
# 2  /80 - total_train_loss: 29.53529 - reconst: 38.94358 - koopeman: 0.72795 - phase: 38.95670 - VAE: 20.30803
# 3  /80 - total_train_loss: 29.37754 - reconst: 38.81931 - koopeman: 0.86359 - phase: 38.88179 - VAE: 19.93618
# 4  /80 - total_train_loss: 29.21665 - reconst: 38.67620 - koopeman: 1.01953 - phase: 38.80436 - VAE: 19.56842
# 5  /80 - total_train_loss: 29.03684 - reconst: 38.49603 - koopeman: 1.20060 - phase: 38.71841 - VAE: 19.17485
# 6  /80 - total_train_loss: 28.82112 - reconst: 38.24363 - koopeman: 1.41245 - phase: 38.60945 - VAE: 18.74649
# 7  /80 - total_train_loss: 28.54009 - reconst: 37.85562 - koopeman: 1.66137 - phase: 38.45120 - VAE: 18.27301
# ...
# 25 /80 - total_train_loss: 15.89948 - reconst: 17.57734 - koopeman: 7.29846 - phase: 16.86739 - VAE: 11.20766
# 26 /80 - total_train_loss: 15.64675 - reconst: 17.33216 - koopeman: 7.11287 - phase: 16.58096 - VAE: 11.28475
# 27 /80 - total_train_loss: 15.30871 - reconst: 17.03184 - koopeman: 6.98713 - phase: 16.18976 - VAE: 11.33460
# 28 /80 - total_train_loss: 14.83191 - reconst: 16.64962 - koopeman: 6.96613 - phase: 15.62852 - VAE: 11.32069
# 29 /80 - total_train_loss: 14.12047 - reconst: 16.11690 - koopeman: 7.09650 - phase: 14.78134 - VAE: 11.21753
# 30 /80 - total_train_loss: 13.03089 - reconst: 15.32447 - koopeman: 7.48598 - phase: 13.47554 - VAE: 10.94650
# 30 /80 - total_test_loss:  0.51919 - reconst: 0.62352 - koopeman: 0.32581 - phase: 0.53265 - VAE: 0.44682
# 31 /80 - total_train_loss: 11.45379 - reconst: 14.08737 - koopeman: 8.28396 - phase: 11.58408 - VAE: 10.42656
# 32 /80 - total_train_loss: 9.60787 - reconst: 12.31321 - koopeman: 9.59466 - phase: 9.38485 - VAE: 9.59207
# 33 /80 - total_train_loss: 8.13463 - reconst: 10.29961 - koopeman: 11.10169 - phase: 7.66559 - VAE: 8.63110
# 34 /80 - total_train_loss: 7.34127 - reconst: 8.66548 - koopeman: 12.03494 - phase: 6.78805 - VAE: 7.96206
# 35 /80 - total_train_loss: 6.92691 - reconst: 7.62905 - koopeman: 12.14123 - phase: 6.36703 - VAE: 7.72901
# 36 /80 - total_train_loss: 6.63686 - reconst: 6.96685 - koopeman: 11.80261 - phase: 6.08615 - VAE: 7.74971
# 37 /80 - total_train_loss: 6.39213 - reconst: 6.48509 - koopeman: 11.34728 - phase: 5.85000 - VAE: 7.84951
# 38 /80 - total_train_loss: 6.17225 - reconst: 6.09449 - koopeman: 10.88888 - phase: 5.63575 - VAE: 7.97133
# 39 /80 - total_train_loss: 5.96878 - reconst: 5.76219 - koopeman: 10.46609 - phase: 5.43457 - VAE: 8.08852
# 40 /80 - total_train_loss: 5.77675 - reconst: 5.47210 - koopeman: 10.08008 - phase: 5.24178 - VAE: 8.19774
# 40 /80 - total_test_loss:  0.24025 - reconst: 0.22513 - koopeman: 0.41169 - phase: 0.21859 - VAE: 0.34375
# 41 /80 - total_train_loss: 5.59310 - reconst: 5.21188 - koopeman: 9.73243 - phase: 5.05476 - VAE: 8.29509
# 42 /80 - total_train_loss: 5.41601 - reconst: 4.97338 - koopeman: 9.40984 - phase: 4.87228 - VAE: 8.38966
# 43 /80 - total_train_loss: 5.24449 - reconst: 4.75506 - koopeman: 9.11853 - phase: 4.69335 - VAE: 8.47359
# 44 /80 - total_train_loss: 5.07725 - reconst: 4.54873 - koopeman: 8.85932 - phase: 4.51746 - VAE: 8.54120
# 45 /80 - total_train_loss: 4.91418 - reconst: 4.35237 - koopeman: 8.62325 - phase: 4.34434 - VAE: 8.60502
# 46 /80 - total_train_loss: 4.75458 - reconst: 4.16689 - koopeman: 8.41277 - phase: 4.17379 - VAE: 8.65355
# 47 /80 - total_train_loss: 4.59862 - reconst: 3.98722 - koopeman: 8.21958 - phase: 4.00617 - VAE: 8.69853
# 48 /80 - total_train_loss: 4.44575 - reconst: 3.81456 - koopeman: 8.05015 - phase: 3.84128 - VAE: 8.72622
# 49 /80 - total_train_loss: 4.29658 - reconst: 3.64847 - koopeman: 7.89528 - phase: 3.68001 - VAE: 8.74487
# 50 /80 - total_train_loss: 4.15132 - reconst: 3.48808 - koopeman: 7.75431 - phase: 3.52216 - VAE: 8.76153
# 50 /80 - total_test_loss:  0.16906 - reconst: 0.14115 - koopeman: 0.32154 - phase: 0.14252 - VAE: 0.36302
# 51 /80 - total_train_loss: 4.00977 - reconst: 3.33317 - koopeman: 7.62985 - phase: 3.36846 - VAE: 8.76201
# 52 /80 - total_train_loss: 3.87280 - reconst: 3.18573 - koopeman: 7.51929 - phase: 3.21927 - VAE: 8.75581
# 53 /80 - total_train_loss: 3.74062 - reconst: 3.04338 - koopeman: 7.41691 - phase: 3.07527 - VAE: 8.74567
# 54 /80 - total_train_loss: 3.61293 - reconst: 2.90918 - koopeman: 7.32838 - phase: 2.93670 - VAE: 8.71605
# 55 /80 - total_train_loss: 3.49108 - reconst: 2.78045 - koopeman: 7.24586 - phase: 2.80423 - VAE: 8.68908
# 56 /80 - total_train_loss: 3.37430 - reconst: 2.65983 - koopeman: 7.17428 - phase: 2.67794 - VAE: 8.64524
# 57 /80 - total_train_loss: 3.26385 - reconst: 2.54569 - koopeman: 7.10380 - phase: 2.55868 - VAE: 8.60413
# 58 /80 - total_train_loss: 3.15904 - reconst: 2.44088 - koopeman: 7.04364 - phase: 2.44573 - VAE: 8.55221
# 59 /80 - total_train_loss: 3.06004 - reconst: 2.34100 - koopeman: 6.98575 - phase: 2.34002 - VAE: 8.49361
# 60 /80 - total_train_loss: 2.96736 - reconst: 2.24984 - koopeman: 6.93419 - phase: 2.24112 - VAE: 8.43289
# 60 /80 - total_test_loss:  0.12157 - reconst: 0.09111 - koopeman: 0.28956 - phase: 0.09130 - VAE: 0.34732
# 61 /80 - total_train_loss: 2.87972 - reconst: 2.16450 - koopeman: 6.88673 - phase: 2.14856 - VAE: 8.36182
# 62 /80 - total_train_loss: 2.79786 - reconst: 2.08701 - koopeman: 6.84380 - phase: 2.06229 - VAE: 8.28968
# 63 /80 - total_train_loss: 2.72051 - reconst: 2.01503 - koopeman: 6.80346 - phase: 1.98198 - VAE: 8.20541
# 64 /80 - total_train_loss: 2.64767 - reconst: 1.94770 - koopeman: 6.76985 - phase: 1.90670 - VAE: 8.11718
# 65 /80 - total_train_loss: 2.57831 - reconst: 1.88292 - koopeman: 6.73645 - phase: 1.83637 - VAE: 8.01880
# 66 /80 - total_train_loss: 2.51218 - reconst: 1.82470 - koopeman: 6.71363 - phase: 1.76976 - VAE: 7.90725
# 67 /80 - total_train_loss: 2.44914 - reconst: 1.76716 - koopeman: 6.69308 - phase: 1.70696 - VAE: 7.79331
# 68 /80 - total_train_loss: 2.38807 - reconst: 1.71418 - koopeman: 6.68457 - phase: 1.64673 - VAE: 7.66153
# 69 /80 - total_train_loss: 2.32792 - reconst: 1.66179 - koopeman: 6.68043 - phase: 1.58883 - VAE: 7.51051
# 70 /80 - total_train_loss: 2.26909 - reconst: 1.60934 - koopeman: 6.69013 - phase: 1.53281 - VAE: 7.34317
# 70 /80 - total_test_loss:  0.09330 - reconst: 0.06556 - koopeman: 0.27893 - phase: 0.06266 - VAE: 0.30304
# 71 /80 - total_train_loss: 2.21073 - reconst: 1.55712 - koopeman: 6.70722 - phase: 1.47796 - VAE: 7.16100
# 72 /80 - total_train_loss: 2.15226 - reconst: 1.50577 - koopeman: 6.74111 - phase: 1.42380 - VAE: 6.95137
# 73 /80 - total_train_loss: 2.09327 - reconst: 1.45396 - koopeman: 6.79014 - phase: 1.36996 - VAE: 6.71540
# 74 /80 - total_train_loss: 2.03352 - reconst: 1.39913 - koopeman: 6.84936 - phase: 1.31637 - VAE: 6.45797
# 75 /80 - total_train_loss: 1.97234 - reconst: 1.34587 - koopeman: 6.93651 - phase: 1.26203 - VAE: 6.15839
# 76 /80 - total_train_loss: 1.90928 - reconst: 1.28951 - koopeman: 7.03892 - phase: 1.20728 - VAE: 5.82338
# 77 /80 - total_train_loss: 1.84444 - reconst: 1.23215 - koopeman: 7.16678 - phase: 1.15167 - VAE: 5.44764
# 78 /80 - total_train_loss: 1.77842 - reconst: 1.17431 - koopeman: 7.31248 - phase: 1.09545 - VAE: 5.04410
# 79 /80 - total_train_loss: 1.70974 - reconst: 1.11801 - koopeman: 7.49556 - phase: 1.03811 - VAE: 4.57511
# ----------Parameter: gamma=1.0----------
# 0  /80 - total_train_loss: 39.10457 - reconst: 39.19530 - koopeman: 0.55785 - phase: 39.10457 - VAE: 21.55146
# 1  /80 - total_train_loss: 38.98512 - reconst: 39.11516 - koopeman: 0.56045 - phase: 38.98512 - VAE: 21.55737
# 2  /80 - total_train_loss: 38.86876 - reconst: 39.06760 - koopeman: 0.57604 - phase: 38.86876 - VAE: 21.51161
# 3  /80 - total_train_loss: 38.73097 - reconst: 39.06091 - koopeman: 0.61116 - phase: 38.73097 - VAE: 21.41349
# 4  /80 - total_train_loss: 38.52651 - reconst: 39.12343 - koopeman: 0.68177 - phase: 38.52651 - VAE: 21.24042
# 5  /80 - total_train_loss: 38.16168 - reconst: 39.32539 - koopeman: 0.82511 - phase: 38.16168 - VAE: 20.94630
# 6  /80 - total_train_loss: 37.44209 - reconst: 39.81447 - koopeman: 1.11530 - phase: 37.44209 - VAE: 20.46256
# 7  /80 - total_train_loss: 36.03492 - reconst: 40.87340 - koopeman: 1.68999 - phase: 36.03492 - VAE: 19.69522
# 8  /80 - total_train_loss: 33.58102 - reconst: 42.93220 - koopeman: 2.75695 - phase: 33.58102 - VAE: 18.55380
# 9  /80 - total_train_loss: 30.04466 - reconst: 46.46211 - koopeman: 4.56211 - phase: 30.04466 - VAE: 17.01937
# 10 /80 - total_train_loss: 26.02829 - reconst: 51.69205 - koopeman: 7.25539 - phase: 26.02829 - VAE: 15.19877
# 10 /80 - total_test_loss:  1.00266 - reconst: 2.29206 - koopeman: 0.37253 - phase: 1.00266 - VAE: 0.59189
# 11 /80 - total_train_loss: 22.54806 - reconst: 58.27414 - koopeman: 10.63983 - phase: 22.54806 - VAE: 13.33884
# 12 /80 - total_train_loss: 20.26369 - reconst: 65.20053 - koopeman: 14.04068 - phase: 20.26369 - VAE: 11.77728
# 13 /80 - total_train_loss: 19.11583 - reconst: 71.16555 - koopeman: 16.66257 - phase: 19.11583 - VAE: 10.74450
# 14 /80 - total_train_loss: 18.62342 - reconst: 75.34605 - koopeman: 18.16799 - phase: 18.62342 - VAE: 10.23279
# 15 /80 - total_train_loss: 18.39447 - reconst: 77.82800 - koopeman: 18.77833 - phase: 18.39447 - VAE: 10.06388
# 16 /80 - total_train_loss: 18.26114 - reconst: 79.22227 - koopeman: 18.89065 - phase: 18.26114 - VAE: 10.05628
# 17 /80 - total_train_loss: 18.16047 - reconst: 79.97749 - koopeman: 18.73282 - phase: 18.16047 - VAE: 10.12597
# 18 /80 - total_train_loss: 18.07225 - reconst: 80.34726 - koopeman: 18.42082 - phase: 18.07225 - VAE: 10.24101
# 19 /80 - total_train_loss: 17.98934 - reconst: 80.50241 - koopeman: 18.02597 - phase: 17.98934 - VAE: 10.38260
# 20 /80 - total_train_loss: 17.90950 - reconst: 80.56485 - koopeman: 17.60353 - phase: 17.90950 - VAE: 10.53522
# 20 /80 - total_test_loss:  0.74712 - reconst: 3.38162 - koopeman: 0.72989 - phase: 0.74712 - VAE: 0.44061
# 21 /80 - total_train_loss: 17.83154 - reconst: 80.57831 - koopeman: 17.17077 - phase: 17.83154 - VAE: 10.69166
# 22 /80 - total_train_loss: 17.75440 - reconst: 80.59125 - koopeman: 16.74670 - phase: 17.75440 - VAE: 10.84631
# 23 /80 - total_train_loss: 17.67739 - reconst: 80.60902 - koopeman: 16.33709 - phase: 17.67739 - VAE: 10.99777
# 24 /80 - total_train_loss: 17.59893 - reconst: 80.61117 - koopeman: 15.93389 - phase: 17.59893 - VAE: 11.14722
# 25 /80 - total_train_loss: 17.51806 - reconst: 80.58889 - koopeman: 15.53049 - phase: 17.51806 - VAE: 11.29910
# 26 /80 - total_train_loss: 17.43251 - reconst: 80.61731 - koopeman: 15.16872 - phase: 17.43251 - VAE: 11.43181
# 27 /80 - total_train_loss: 17.33986 - reconst: 80.60653 - koopeman: 14.80227 - phase: 17.33986 - VAE: 11.56910
# 28 /80 - total_train_loss: 17.23616 - reconst: 80.59579 - koopeman: 14.45829 - phase: 17.23616 - VAE: 11.69361
# 29 /80 - total_train_loss: 17.11556 - reconst: 80.54438 - koopeman: 14.12512 - phase: 17.11556 - VAE: 11.80985
# 30 /80 - total_train_loss: 16.96830 - reconst: 80.49759 - koopeman: 13.82326 - phase: 16.96830 - VAE: 11.90879
# 30 /80 - total_test_loss:  0.71022 - reconst: 3.37828 - koopeman: 0.57273 - phase: 0.71022 - VAE: 0.49698
# 31 /80 - total_train_loss: 16.77826 - reconst: 80.42337 - koopeman: 13.55135 - phase: 16.77826 - VAE: 11.98704
# 32 /80 - total_train_loss: 16.51668 - reconst: 80.28992 - koopeman: 13.31766 - phase: 16.51668 - VAE: 12.03540
# 33 /80 - total_train_loss: 16.12838 - reconst: 80.07245 - koopeman: 13.14258 - phase: 16.12838 - VAE: 12.03880
# 34 /80 - total_train_loss: 15.50034 - reconst: 79.67585 - koopeman: 13.05839 - phase: 15.50034 - VAE: 11.96977
# 35 /80 - total_train_loss: 14.41090 - reconst: 79.04489 - koopeman: 13.18556 - phase: 14.41090 - VAE: 11.74985
# 36 /80 - total_train_loss: 12.57933 - reconst: 78.08253 - koopeman: 13.76486 - phase: 12.57933 - VAE: 11.24198
# 37 /80 - total_train_loss: 10.12290 - reconst: 77.17102 - koopeman: 15.22271 - phase: 10.12290 - VAE: 10.26800
# 38 /80 - total_train_loss: 7.98182 - reconst: 77.28091 - koopeman: 17.55536 - phase: 7.98182 - VAE: 8.96417
# 39 /80 - total_train_loss: 6.82024 - reconst: 78.79215 - koopeman: 19.74444 - phase: 6.82024 - VAE: 7.88865
# 40 /80 - total_train_loss: 6.29016 - reconst: 80.31457 - koopeman: 20.92342 - phase: 6.29016 - VAE: 7.34845
# 40 /80 - total_test_loss:  0.25807 - reconst: 3.39217 - koopeman: 0.88254 - phase: 0.25807 - VAE: 0.30214
# 41 /80 - total_train_loss: 5.97133 - reconst: 80.95277 - koopeman: 21.27284 - phase: 5.97133 - VAE: 7.17801
# 42 /80 - total_train_loss: 5.71099 - reconst: 81.01353 - koopeman: 21.22684 - phase: 5.71099 - VAE: 7.17367
# 43 /80 - total_train_loss: 5.47257 - reconst: 81.01219 - koopeman: 21.06614 - phase: 5.47257 - VAE: 7.22278
# 44 /80 - total_train_loss: 5.24470 - reconst: 80.97062 - koopeman: 20.87909 - phase: 5.24470 - VAE: 7.28469
# 45 /80 - total_train_loss: 5.02315 - reconst: 80.87757 - koopeman: 20.67460 - phase: 5.02315 - VAE: 7.35771
# 46 /80 - total_train_loss: 4.80658 - reconst: 80.79765 - koopeman: 20.48383 - phase: 4.80658 - VAE: 7.42299
# 47 /80 - total_train_loss: 4.59480 - reconst: 80.64292 - koopeman: 20.28637 - phase: 4.59480 - VAE: 7.49386
# 48 /80 - total_train_loss: 4.38760 - reconst: 80.54784 - koopeman: 20.11565 - phase: 4.38760 - VAE: 7.55565
# 49 /80 - total_train_loss: 4.18632 - reconst: 80.44730 - koopeman: 19.95533 - phase: 4.18632 - VAE: 7.61865
# 50 /80 - total_train_loss: 3.99071 - reconst: 80.30767 - koopeman: 19.80069 - phase: 3.99071 - VAE: 7.67703
# 50 /80 - total_test_loss:  0.16109 - reconst: 3.38458 - koopeman: 0.82388 - phase: 0.16109 - VAE: 0.32243
# 51 /80 - total_train_loss: 3.80192 - reconst: 80.20473 - koopeman: 19.66408 - phase: 3.80192 - VAE: 7.73158
# 52 /80 - total_train_loss: 3.62044 - reconst: 80.10813 - koopeman: 19.54555 - phase: 3.62044 - VAE: 7.78993
# 53 /80 - total_train_loss: 3.44708 - reconst: 79.97786 - koopeman: 19.43221 - phase: 3.44708 - VAE: 7.84262
# 54 /80 - total_train_loss: 3.28184 - reconst: 79.91379 - koopeman: 19.33658 - phase: 3.28184 - VAE: 7.88976
# 55 /80 - total_train_loss: 3.12535 - reconst: 79.81540 - koopeman: 19.24507 - phase: 3.12535 - VAE: 7.93499
# 56 /80 - total_train_loss: 2.97746 - reconst: 79.71235 - koopeman: 19.16465 - phase: 2.97746 - VAE: 7.97612
# 57 /80 - total_train_loss: 2.83858 - reconst: 79.60557 - koopeman: 19.08054 - phase: 2.83858 - VAE: 8.01804
# 58 /80 - total_train_loss: 2.70812 - reconst: 79.52183 - koopeman: 19.01398 - phase: 2.70812 - VAE: 8.05336
# 59 /80 - total_train_loss: 2.58626 - reconst: 79.40935 - koopeman: 18.94147 - phase: 2.58626 - VAE: 8.08860
# 60 /80 - total_train_loss: 2.47268 - reconst: 79.30576 - koopeman: 18.87582 - phase: 2.47268 - VAE: 8.12192
# 60 /80 - total_test_loss:  0.10058 - reconst: 3.35617 - koopeman: 0.78858 - phase: 0.10058 - VAE: 0.33853
# 61 /80 - total_train_loss: 2.36658 - reconst: 79.20351 - koopeman: 18.81193 - phase: 2.36658 - VAE: 8.15331
# 62 /80 - total_train_loss: 2.26793 - reconst: 79.12618 - koopeman: 18.75393 - phase: 2.26793 - VAE: 8.18183
# 63 /80 - total_train_loss: 2.17624 - reconst: 78.98663 - koopeman: 18.68682 - phase: 2.17624 - VAE: 8.21118
# 64 /80 - total_train_loss: 2.09056 - reconst: 78.91259 - koopeman: 18.62958 - phase: 2.09056 - VAE: 8.23769
# 65 /80 - total_train_loss: 2.01073 - reconst: 78.75143 - koopeman: 18.55592 - phase: 2.01073 - VAE: 8.26761
# 66 /80 - total_train_loss: 1.93598 - reconst: 78.65769 - koopeman: 18.49458 - phase: 1.93598 - VAE: 8.29210
# 67 /80 - total_train_loss: 1.86599 - reconst: 78.55049 - koopeman: 18.42798 - phase: 1.86599 - VAE: 8.31758
# 68 /80 - total_train_loss: 1.80006 - reconst: 78.44189 - koopeman: 18.36680 - phase: 1.80006 - VAE: 8.33930
# 69 /80 - total_train_loss: 1.73782 - reconst: 78.31259 - koopeman: 18.29942 - phase: 1.73782 - VAE: 8.35968
# 70 /80 - total_train_loss: 1.67876 - reconst: 78.20730 - koopeman: 18.23757 - phase: 1.67876 - VAE: 8.37969
# 70 /80 - total_test_loss:  0.06872 - reconst: 3.25830 - koopeman: 0.75648 - phase: 0.06872 - VAE: 0.35186
# 71 /80 - total_train_loss: 1.62248 - reconst: 78.12329 - koopeman: 18.17678 - phase: 1.62248 - VAE: 8.39624
# 72 /80 - total_train_loss: 1.56859 - reconst: 78.01096 - koopeman: 18.12141 - phase: 1.56859 - VAE: 8.40674
# 73 /80 - total_train_loss: 1.51677 - reconst: 77.92705 - koopeman: 18.07328 - phase: 1.51677 - VAE: 8.41330
# 74 /80 - total_train_loss: 1.46659 - reconst: 77.82574 - koopeman: 18.01358 - phase: 1.46659 - VAE: 8.42586
# 75 /80 - total_train_loss: 1.41785 - reconst: 77.75436 - koopeman: 17.98420 - phase: 1.41785 - VAE: 8.41936
# 76 /80 - total_train_loss: 1.37017 - reconst: 77.69025 - koopeman: 17.95251 - phase: 1.37017 - VAE: 8.41472
# 77 /80 - total_train_loss: 1.32345 - reconst: 77.63088 - koopeman: 17.93346 - phase: 1.32345 - VAE: 8.41289
# 78 /80 - total_train_loss: 1.27741 - reconst: 77.57167 - koopeman: 17.91208 - phase: 1.27741 - VAE: 8.42288
# 79 /80 - total_train_loss: 1.23199 - reconst: 77.56114 - koopeman: 17.93078 - phase: 1.23199 - VAE: 8.41715

# %%
params = {
    "alpha": 0.45, 
    "beta": 0.15, 
    "gamma": 0.25,
    "delta": 0.15
}

n_epoch = 600
output_dim = 30

_, _= eval_hyperparameter(experiment_mode=False, **params)

# %% [markdown]
# ##### Interpretation
# We experimented different ratios of coefficients to find the best combination of values. The first approach was a "dumb" one. We tested, for each coefficient, a set of values {0.1, 0.3, 0.5, 0.8, 1.0} and set the three other coeeficients at an equal participation to the remainder. We notice different behaviour for the total loss for each coefficient. For instance, increasing the alpha coefficient, weighting the reconstruction loss weight in the total loss led to a faster convergence. However, despite these different behaviours, the higher the number of epochs the more similar the losses become. We notice an interesting behaviour regarding the evolution of the loss, with a plateau appearing around the 11th epoch not matter the coefficient set.

# %% [markdown]
# #### Verification

# %% [markdown]
# **Question 4.** : We want to ensure the Koopman operator is stable. This can be verified by checking whether its spectral radius $\rho(\mathbf{K})\le 1$. Plot the eigenvalues of the Koopman operator in order to verify the bound on its spectral radius. You can use the [`numpy.linalg.eig`](https://numpy.org/doc/stable/reference/generated/numpy.linalg.eig.html) function to retrieve the eigenvalues of a matrix.

# %%
eigenval, _ = np.linalg.eig(koopman_operator.koopman_matrix.cpu().detach().numpy())

plt.scatter(np.imag(eigenval),np.real(eigenval))
plt.plot(np.sqrt(1.0) * np.cos(np.linspace(0, 2*np.pi, 100)),
         np.sqrt(1.0) * np.sin(np.linspace(0, 2*np.pi, 100)), 
         color='r', linestyle='-')
plt.xlabel('$\Im(\lambda)$')
plt.ylabel('$\Re(\lambda)$')
plt.axis("equal")
plt.show()

# %%
def plot_results():
    n_grid = 30
    x1_min, x1_max = -2, 2
    x2_min, x2_max = -2, 2

    array_x1 = np.linspace(x1_min, x1_max, n_grid, dtype=np.float32)
    array_x2 = np.linspace(x2_min, x2_max, n_grid, dtype=np.float32)
    matrix_grid_x1, matrix_grid_x2 = np.meshgrid(array_x1, array_x2)

    array3d_dynamics = np.zeros((n_grid, n_grid, 2), dtype=np.float32)

    for i in range(n_grid):
        for j in range(n_grid):
            x1 = matrix_grid_x1[i, j]
            x2 = matrix_grid_x2[i, j]
            array3d_dynamics[i, j, :] = duffing(np.array([x1, x2]))

    # Set evaluation mode
    autoencoder.eval()
    koopman_operator.eval()

    array3d_dynamics_pred = np.zeros((n_grid, n_grid, 2), dtype=np.float32)

    for i in range(n_grid):
        for j in range(n_grid):
            x1 = matrix_grid_x1[i, j]
            x2 = matrix_grid_x2[i, j]
            tensor2d_x = torch.tensor([[x1, x2]], dtype=torch.float32).to(device)
            tensor2d_observable = autoencoder.encoder(tensor2d_x)
            tensor2d_koopman_observable_next = koopman_operator(tensor2d_observable)
            tensor2d_predict_x_next = autoencoder.decoder(tensor2d_koopman_observable_next)
            array_x_next = tensor2d_predict_x_next.cpu().detach().numpy().ravel()

            # Here we compute a discretised version of the derivative thanks to the Koopman operator
            # and the learned encoder/decoder

            # (x_{k+1} - x_k) / \delta_t = f(x_k) is approximated by (f is duffing here)
            # (Decod(K(Encod(x_k))) - x_k) / \delta_t

            delta_time = (t_max / n_iter)
            array3d_dynamics_pred[i, j, :] = (array_x_next - [x1, x2]) / delta_time

    fig = plt.figure(figsize=(15, 5))
    ax = fig.add_subplot(131)
    ax.quiver(matrix_grid_x1,
            matrix_grid_x2,
            array3d_dynamics[:, :, 0],
            array3d_dynamics[:, :, 1], scale=10)
    ax.set_title('True')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')

    ax = fig.add_subplot(132)
    ax.quiver(matrix_grid_x1,
            matrix_grid_x2,
            array3d_dynamics_pred[:, :, 0],
            array3d_dynamics_pred[:, :, 1], scale=10)

    ax.set_title('Prediction')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')

    # Compute the error
    matrix_error = np.linalg.norm(array3d_dynamics - array3d_dynamics_pred, axis=2)
    matrix_error_log = np.log10(matrix_error + 1e-10)

    ax = fig.add_subplot(133)
    cp = ax.contourf(matrix_grid_x1,
                    matrix_grid_x2,
                    matrix_error_log)

    fig.colorbar(cp)
    ax.set_title('Error in log scale')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    plt.show()

# %%
plot_results()

# %% [markdown]
# ### Continuous in time case
#
# Considering $x_k$ as the observation of a state at time $t = k \delta$, and $x_{k+1}$ the state at time $t+ \delta$, for $\delta \rightarrow 0$  it is also possible to define the continuous-time infinitesimal generator of the Koopman operator family as
#
# $$
# \mathcal{L} g (x_k)  = \lim_{\delta \rightarrow 0} \frac{\mathcal{K}g(x_k)- g(x_{k})}{\delta} = \frac{g \circ F (x_k) -x_k}{\delta}
# $$
#
# The pevious expression defines the Lie derivative, and for this reason $\mathcal{L}$ is known as the Lie operator. $\mathcal{L}$ describes the continuous dynamics of the observables in the Koopman space:
#
# $$
# \dot{g} (x) = \mathcal{L} g(x).
# $$
#
# The latter can be further expressed as:
#
# $$
# \dot{g} (x(t)) = \frac{dg(x)}{dt} = \nabla_x g \frac{dx}{dt} = \nabla_x g \cdot f(x) =\mathcal{L} g(x).
# $$
#
# Given $g_{\theta}$, $\varphi_{\rho}$ and $\mathbf{L}_{\phi}$ three parameterized functions, the following conditions hold:
#
# 1.   Reconstruction error
#      $$
#      \Vert \varphi_\rho (g_\theta(x)) - x  \Vert = 0
#      $$
# 2.   Prediction error in Koopman space
#      $$
#      \Vert \mathbf{L_{\phi}} g_{\theta} ( x ) - \nabla g_{\theta} \cdot f(x)  \Vert = 0
#      $$
# 3.   Prediction error in the phase space
#      $$
#      \Vert \varphi_{\rho} \left( \mathbf{L_{\phi}} g_{\theta} ( x )\right) - f(x) \Vert = 0
#      $$
#
# **Important Remark: As long as the system $f$ is known, the three errors can be computed without data belonging to trajectories.**

# %%
# Create a dataset for continuous Koopman
# with the same amount of points of the Discontinuous Koopman case
# But here no need to have continuous trajectories
matrix_x0 = (np.random.rand(n_initial_conditions * (n_iter - 1), 2) - 0.5) * 4
matrix_system_derivative_data = np.zeros(matrix_x0.shape)
for i in tqdm(range(matrix_x0.shape[0])):
    matrix_system_derivative_data[i, :] = duffing(matrix_x0[i, :])
# Out:
# 100%|██████████| 299940/299940 [00:00<00:00, 921324.13it/s]

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ax.quiver(matrix_x0[::50, 0],
          matrix_x0[::50, 1],
          matrix_system_derivative_data[::50, 0] * 0.2,
          matrix_system_derivative_data[::50, 1] * 0.2, scale=10)
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
plt.show()

# %%
# create the models
feature_dim = 2  # dimension of the Duffing oscillator
hidden_layer = 5  # number of hidden layers in g (ENCODER) and \varphi (DECODER) 
output_dim = 30  # dimension in Koopman space
batch_size = 2000  # data per batch

# %%
(matrix_x_data_train,
 matrix_x_data_test,
 matrix_x_next_data_train,
 matrix_x_next_data_test) = train_test_split(matrix_x0,
                                             matrix_system_derivative_data,
                                             test_size=0.2)

# Cast type to float32
matrix_x_data_train = matrix_x_data_train.astype(np.float32)
matrix_x_data_test = matrix_x_data_test.astype(np.float32)
matrix_x_next_data_train = matrix_x_next_data_train.astype(np.float32)
matrix_x_next_data_test = matrix_x_next_data_test.astype(np.float32)

print(matrix_x_data_train.shape,
      matrix_x_data_test.shape,
      matrix_x_next_data_train.shape,
      matrix_x_next_data_test.shape)

torch_dataset_train = TensorDataset(torch.from_numpy(matrix_x_data_train),
                                    torch.from_numpy(matrix_x_next_data_train))
torch_dataset_test = TensorDataset(torch.from_numpy(matrix_x_data_test),
                                   torch.from_numpy(matrix_x_next_data_test))

train_dataloader = DataLoader(torch_dataset_train,
                              batch_size=batch_size,
                              shuffle=True)
test_dataloader = DataLoader(torch_dataset_test,
                             batch_size=batch_size,
                             shuffle=True)
# Out:
# (239952, 2) (59988, 2) (239952, 2) (59988, 2)

# %%
class Encoder(nn.Module):
    def __init__(self, list_layer_dim):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1):
            dim_input = self.list_layer_dim[i]
            dim_output = self.list_layer_dim[i + 1]
            self.list_FC.append(nn.Linear(dim_input, dim_output))

    def forward(self, tensor2d_x):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Decoder(nn.Module):
    def __init__(self, list_layer_dim):
        super().__init__()
        self.list_layer_dim = list_layer_dim
        self.list_FC = nn.ModuleList()
        for i in range(len(self.list_layer_dim) - 1, 0, -1):
            dim_input = self.list_layer_dim[i]
            dim_output = self.list_layer_dim[i - 1]
            self.list_FC.append(nn.Linear(dim_input, dim_output))

    def forward(self, tensor2d_x):
        for i in range(len(self.list_layer_dim) - 2):
            tensor2d_x = F.elu(self.list_FC[i](tensor2d_x))
        return self.list_FC[-1](tensor2d_x)

# %%
class Autoencoder(nn.Module):
    def __init__(self, feature_dim, hidden_layer, output_dim):
        super().__init__()

        list_layer_dim = \
            [output_dim if i == hidden_layer
             else feature_dim + i * (output_dim - feature_dim) // hidden_layer
             for i in range(hidden_layer + 1)]

        self.encoder = Encoder(list_layer_dim)
        self.decoder = Decoder(list_layer_dim)

    def forward(self, tensor2d_x: torch.Tensor):
        tensor2d_x = self.encoder(tensor2d_x)
        return self.decoder(tensor2d_x)

# %% [markdown]
# The Lie operator must be defined such that it will be always stable by construction.
# To do that, we consider a matrix of parameters $\Psi \in \mathbb{R}^{m \times m}$ and a vector of parameters $\Gamma \in \mathbb{R}^m$. The resulting Lie operator will be of the form:
#
# $$
# \mathbf{L} = (\Psi - \Psi^T) - \text{diag}(\vert \Gamma \vert)
# $$
#
# with eigenvalues whose real part $\Re(\lambda) \leq 0$ .
# See https://math.stackexchange.com/questions/952233/eigenvalues-of-the-sum-of-a-diagonal-matrix-and-a-skew-symmetric-matrix for the mathematical proof (identify the matrix). Moreover if $\lambda \in \mathbb{C}$ is an eigenvalue of $\mathbf{L}$, it turns out that its real part $\Re(\lambda) \propto \Vert \Gamma \Vert$, i.e. it only depends on $\Gamma$.
#
# Remark: $- \text{diag}(\vert \Gamma \vert)$ is always a diagonal matrix with non-positive elements.

# %% [markdown]
# **Question 4.** : As you did for the discrete case, you now have to implement the `LieModule` module. It should have the form indicated above to guarantee $\Re(\lambda) \leq 0$. Check that the initialization fulfills this property.

# %%
class LieModule(nn.Module):
    def __init__(self, lie_operator_dim: int):
        super().__init__()
        self.lie_operator_dim = lie_operator_dim

        self.psi  = torch.nn.Parameter(torch.randn(lie_operator_dim, lie_operator_dim))
        self.diag = torch.nn.Parameter(torch.diag(torch.abs(torch.randn(lie_operator_dim))))

        torch.nn.init.kaiming_uniform_(self.psi, a=np.sqrt(5))
        
    def forward(self, tensor2d_x: torch.Tensor):
        if tensor2d_x.shape[1] != self.lie_operator_dim:
            sys.exit(f'Wrong Input Features. Please use tensor'
                     f' with {self.lie_operator_dim} Input Features')
            
        self.L = self.psi - self.psi.t() - self.diag    

        return torch.matmul(tensor2d_x, self.L.t())
    
    def get_L(self):
        return self.L

# %%
autoencoder = Autoencoder(feature_dim, hidden_layer, output_dim).to(device)
lie_operator = LieModule(output_dim).to(device)
print(autoencoder)
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=2, out_features=7, bias=True)
#       (1): Linear(in_features=7, out_features=13, bias=True)
#       (2): Linear(in_features=13, out_features=18, bias=True)
#       (3): Linear(in_features=18, out_features=24, bias=True)
#       (4): Linear(in_features=24, out_features=30, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (list_FC): ModuleList(
#       (0): Linear(in_features=30, out_features=24, bias=True)
#       (1): Linear(in_features=24, out_features=18, bias=True)
#       (2): Linear(in_features=18, out_features=13, bias=True)
#       (3): Linear(in_features=13, out_features=7, bias=True)
#       (4): Linear(in_features=7, out_features=2, bias=True)
#     )
#   )
# )

# %% [markdown]
# Some tricks are needed to train. If the autoencoder and the Lie model are learned at the same speed, the training turns out to be highly unstable since the three loss functions have moving targets. For this reason, the Lie learning rate has been chosen smaller than the autoencoder one.

# %%
learning_rate_autoencoder = 0.0001
learning_rate_lie = 0.00001

optimiser_autoencoder = torch.optim.Adam(autoencoder.parameters(),
                                         lr=learning_rate_autoencoder,
                                         weight_decay=1e-3)
optimiser_lie = torch.optim.Adam(lie_operator.parameters(),
                                 lr=learning_rate_lie,
                                 weight_decay=1e-3)

# %% [markdown]
# A further loss is considered to stabilize the learning stage. The state $x$ belongs to a compact set, since it is the solution of a dissipative dynamical system. This is not true for $g(x)$ (we need to choose appropriate activation functions to have appropriate Liptchitz guarantees). To avoid discrepancies in magnitudes of $g_i(x)$, a regularization loss is added:
#
# $$
# \mu = \frac{1}{m} \sum_m g_i(x) = 0  \quad \text{and} \quad  \sigma = \left( \frac{1}{m}\sum_m(g_i(x)-\mu)^2 \right)^{1/2} = 1
# $$
#
# inspired by VAE.
#
# For the training to be smooth, the encoder parameters are not affected by the **prediction loss in phase space**. This is based on an empirical observation and is motivated by the fact that the encoder appears in the three losses and plays a competitive role against the decoder and the Lie model. This should not affect the results since the encoder remains coupled with the decoder in the **reconstruction loss** and with the Lie operator in the **prediction loss in Koopman space**.

# %% [markdown]
# **Question 5.** : Implement the loss function similarly to what you did for the **Question 2.** Note that here you should use the dynamics $f$ and its values for a set of points belonging to the domain $\left[ -2, 2 \right]^2$ while no data from proper **trajectories** are needed.

# %%
# Implement the loss function here
# See the training process below to identify the different components of the loss
def loss(tensor2d_x: torch.Tensor, #X_
         tensor2d_x_next: torch.Tensor, #dX_
         tensor2d_decoded_x: torch.Tensor,#X_recon
         tensor2d_observable: torch.Tensor,#gX
         tensor2d_lie_observable_next: torch.Tensor,#dgX
         tensor2d_predict_x_next: torch.Tensor,#dX_recon
         tensor2d_jvp: torch.Tensor,#jvp
         alpha: float = 0.25,
         beta:  float = 0.25,
         delta: float = 0.25,
         theta: float = 0.25,
         ):  
  
    for p in autoencoder.encoder.parameters():
      p.requires_grad = False
    
    reconst_loss = F.mse_loss(tensor2d_decoded_x, tensor2d_x) 
    Lie_loss     = F.mse_loss(tensor2d_lie_observable_next, tensor2d_jvp) 
    phase_loss   = F.mse_loss(tensor2d_predict_x_next, tensor2d_x_next)
    vae_loss     = torch.abs(torch.mean(tensor2d_observable)) + torch.abs(torch.std(tensor2d_observable)-1)

    for p in autoencoder.encoder.parameters():
      p.requires_grad = True

    total_loss = alpha * reconst_loss + beta * Lie_loss + delta * phase_loss + theta * vae_loss

    return total_loss#, reconst_loss, Lie_loss, phase_loss, vae_loss

# %% [markdown]
# **Since trajectories are not needed**, random states can be sampled from the system manifold $x_1 \in [-2, 2]$, $x_2 \in [-2, 2]$.

# %%
n_batch = len(train_dataloader)
n_epoch = 50  # To be tuned 

for epoch in range(n_epoch):
    autoencoder.train()
    lie_operator.train()
    total_train_loss = 0
    total_loss1, total_loss2, total_loss3, total_loss4 = 0, 0, 0, 0
    for tensor2d_batch_x, tensor2d_batch_x_next in train_dataloader:
        tensor2d_batch_x = tensor2d_batch_x.to(device) 
        tensor2d_batch_x_next = tensor2d_batch_x_next.to(device) 

        optimiser_autoencoder.zero_grad()
        optimiser_lie.zero_grad()

        (tensor2d_observable, tensor2d_jvp) = \
            autograd.functional.jvp(autoencoder.encoder,
                                    tensor2d_batch_x,
                                    tensor2d_batch_x_next,
                                    create_graph=True)

        tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable) 

        # tensor2d_lie_observable_next, L = lie_operator(tensor2d_observable)
        tensor2d_lie_observable_next = lie_operator(tensor2d_observable)
        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_lie_observable_next) 

        tensor_loss_val = \
            loss(tensor2d_x=tensor2d_batch_x,                               
                 tensor2d_x_next=tensor2d_batch_x_next,                     
                 tensor2d_decoded_x=tensor2d_decoded_x,                     
                 tensor2d_observable=tensor2d_observable,                   
                 tensor2d_lie_observable_next=tensor2d_lie_observable_next, 
                 tensor2d_predict_x_next=tensor2d_predict_x_next,           
                 tensor2d_jvp=tensor2d_jvp)                                 

        tensor_loss_val.backward()
        optimiser_autoencoder.step()
        optimiser_lie.step()

        if epoch % 1 == 0:
            total_train_loss += tensor_loss_val.item()
    if epoch % 1 == 0:
        print(epoch, total_train_loss)

    if epoch % 10 == 0:
        autoencoder.eval()
        lie_operator.eval()
        with torch.no_grad():
            total_test_loss = 0
            total_loss1, total_loss2, total_loss3, total_loss4 = 0, 0, 0, 0
            for tensor2d_batch_x, tensor2d_batch_x_next in test_dataloader:
                tensor2d_batch_x = tensor2d_batch_x.to(device)
                tensor2d_batch_x_next = tensor2d_batch_x_next.to(device)

                (tensor2d_observable, tensor2d_jvp) = \
                    autograd.functional.jvp(autoencoder.encoder,
                                            tensor2d_batch_x,
                                            tensor2d_batch_x_next,
                                            create_graph=True)
                tensor2d_decoded_x = autoencoder.decoder(tensor2d_observable)

                # tensor2d_lie_observable_next, _ = lie_operator(tensor2d_observable)
                tensor2d_lie_observable_next = lie_operator(tensor2d_observable)
                tensor2d_predict_x_next = autoencoder.decoder(tensor2d_lie_observable_next)

                tensor_loss_val = \
                    loss(tensor2d_x=tensor2d_batch_x,
                         tensor2d_x_next=tensor2d_batch_x_next,
                         tensor2d_decoded_x=tensor2d_decoded_x,
                         tensor2d_observable=tensor2d_observable,
                         tensor2d_lie_observable_next=tensor2d_lie_observable_next,
                         tensor2d_predict_x_next=tensor2d_predict_x_next,
                         tensor2d_jvp=tensor2d_jvp)

                total_test_loss += tensor_loss_val.item()
            print('-' * 50, 'TEST', '-' * 50)
            print(epoch, total_test_loss)
            print('-' * 106)
# Out:
# 0 148.98881709575653
# -------------------------------------------------- TEST --------------------------------------------------
# 0 36.824421644210815
# ----------------------------------------------------------------------------------------------------------
# 1 143.178027510643
# 2 126.14033508300781
# 3 104.14343309402466
# 4 88.69246703386307
# 5 67.50912642478943
# 6 51.26255190372467
# 7 42.693430453538895
# 8 37.75562819838524
# 9 34.74064892530441
# 10 32.62333859503269
# -------------------------------------------------- TEST --------------------------------------------------
# 10 7.956836253404617
# ----------------------------------------------------------------------------------------------------------
# 11 31.041118055582047
# 12 29.769608348608017
# 13 28.700459763407707
# 14 27.734168261289597
# 15 26.815795227885246
# 16 25.92512372136116
# 17 25.02156026661396
# 18 24.07420165836811
# 19 23.06130723655224
# 20 21.925122797489166
# -------------------------------------------------- TEST --------------------------------------------------
# 20 5.330289080739021
# ----------------------------------------------------------------------------------------------------------
# 21 20.559675067663193
# 22 18.849112153053284
# 23 16.697296179831028
# 24 14.169803895056248
# 25 11.52147302031517
# 26 9.111645184457302
# 27 7.1964808739721775
# 28 5.790604911744595
# 29 4.791001819074154
# 30 4.0609688851982355
# -------------------------------------------------- TEST --------------------------------------------------
# 30 0.9439681600779295
# ----------------------------------------------------------------------------------------------------------
# 31 3.544223263859749
# 32 3.13489075191319
# 33 2.8265844881534576
# 34 2.581180740147829
# 35 2.366998067125678
# 36 2.193479822948575
# 37 2.0501692350953817
# 38 1.9173835394904017
# 39 1.8029833873733878
# 40 1.7030783295631409
# -------------------------------------------------- TEST --------------------------------------------------
# 40 0.4150315886363387
# ----------------------------------------------------------------------------------------------------------
# 41 1.6184029718860984
# 42 1.5466425623744726
# 43 1.4724225187674165
# 44 1.4186281589791179
# 45 1.3615555157884955
# 46 1.3046200582757592
# 47 1.259673842228949
# 48 1.2193024652078748
# 49 1.1771366531029344

# %% [markdown]
# ### Verification

# %% [markdown]
# **Question 6.** : As in the **Question 3.** we want to ensure the Lie operator is stable. This can be verified by checking that the real part of the eigenvalues is negative. Plot the relevant eigenvalues of the Lie operator. You can use the [`numpy.linalg.eig`](https://numpy.org/doc/stable/reference/generated/numpy.linalg.eig.html) function to retrieve the eigenvalues of a matrix.

# %%
Lambda, _ = np.linalg.eig(lie_operator.get_L().detach().cpu().numpy())

plt.figure(figsize=(10,5))
plt.scatter(np.imag(Lambda), np.real(Lambda))
plt.axhline(0, color='r', linestyle='--')
plt.xlabel('$\Im(\lambda)$')
plt.ylabel('$\Re(\lambda)$')
plt.title('Eigenvalues')
plt.show()

# %%
n_grid = 30
array_x1 = np.linspace(x1_min, x1_max, n_grid, dtype=np.float32)
array_x2 = np.linspace(x2_min, x2_max, n_grid, dtype=np.float32)
matrix_grid_x1, matrix_grid_x2 = np.meshgrid(array_x1, array_x2)

array3d_dynamics = np.zeros((n_grid, n_grid, 2))

for i in range(n_grid):
    for j in range(n_grid):
        array3d_dynamics[i, j, :] = duffing(np.array([matrix_grid_x1[i, j], matrix_grid_x2[i, j]]))

autoencoder.eval()
lie_operator.eval()
array3d_dynamics_pred = np.zeros((n_grid, n_grid, 2))
for i in range(n_grid):
    for j in range(n_grid):
        x1 = matrix_grid_x1[i, j]
        x2 = matrix_grid_x2[i, j]
        tensor2d_x = torch.tensor([[x1, x2]], dtype=torch.float32).to(device)
        tensor2d_observable = autoencoder.encoder(tensor2d_x)
        tensor2d_lie_observable_next = lie_operator(tensor2d_observable)
        tensor2d_predict_x_next = autoencoder.decoder(tensor2d_lie_observable_next)
        array_x_next = tensor2d_predict_x_next.cpu().detach().numpy().ravel()

        array3d_dynamics_pred[i, j, :] = array_x_next

# %%
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(131)
ax.quiver(matrix_grid_x1, matrix_grid_x2, array3d_dynamics[:, :, 0], array3d_dynamics[:, :, 1], scale=10)
ax.set_title('True')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

ax = fig.add_subplot(132)
ax.quiver(matrix_grid_x1, matrix_grid_x2, array3d_dynamics_pred[:, :, 0], array3d_dynamics_pred[:, :, 1], scale=10)
ax.set_title('Prediction')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

ax = fig.add_subplot(133)
cp = ax.contourf(matrix_grid_x1, matrix_grid_x2,
                 np.log(np.linalg.norm(array3d_dynamics - array3d_dynamics_pred, axis=2)))
fig.colorbar(cp)
ax.set_title('Error in log scale')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

plt.show()

# %% [markdown]
# **Question 7.** : Compare and comment below the two approaches (discrete vs continuous operator).

# %% [markdown]
# The goal of this work was to evaluate two different approaches aimed at simulating the dynamics of a non-linear system using Koopman's theory.
#
# * The first approach is based on the discrete case. To do so, we used the Koopman operator and forced the spectral radius to be smaller than one by normalizing the Koopman matrix with the right term of the Perron-Frobenius inequality. Given the complexity of the problem, we used four different losses in order to help the model learn the system. We weighted each loss with a coefficient and experimented with different sets of weights. We added a regularization loss inpired by the Variational Autoencoder to quantize probability distribution error. This regularization enforces the mean to be close to $0$ and the standard deviation to be close to $1$ in order to avoid magnitude discrepancies. We finally used the following values:
#
# $$L_{total} = \alpha \times L_{Reconstruction} + \beta \times L_{Koopman} + \gamma \times L_{Phase} + \delta \times L_{VAE}$$
#
# with $\alpha = 0.45, \beta = 0.15, \gamma = 0.25$ and $\delta = 0.15$
#
# * The second approach is based on the continuous case. This method uses the Lie operator, with a Lie Matrix with negative eigenvalues in order to help stability. The four losses described previously were used for this case aswell but the tuning of the different coefficient was a lot faster. Indeed this method led to much better results than the previous one. With only fifty epochs, we reached a better reconstruction than the first method had with 600 epochs.

# %% [markdown]
# **Question 8.** : Mention one of the important research paper related to this framework. Namely, _deep learning of dynamical systems with the Koopman operator_. Explain shortly the reason of your choice.

# %% [markdown]
# I chose the paper "Learning Deep Neural Network Representations for Koopman Operators of Nonlinear Dynamical Systems". I decided to use this paper, partially because it was the first to come up on google scholar, but also because it develops methods that efficiently approximate these Koopman operators using deep neural networks, thereby making it feasible to analyze complex nonlinear systems with the computational benefits and insights provided by linear system theory. Their method provide a more scalable and practical approach to capturing the essential dynamics of these systems without sacrificing the nuanced details inherent in nonlinear behaviors. This work bridges the gap between theoretical physics and practical machine learning applications.

# %% [markdown]
# **-- PLEASE SUBMIT YOUR COMPLETED NOTEBOOK WITH CELL OUTPUTS --**
